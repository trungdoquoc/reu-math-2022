# %%
import datetime
from pytz import timezone

# from collections import OrderedDict
from copy import deepcopy

import pickle
import time
import numpy as np
import copy
import torch
import torch.nn as nn
import math
from torch.autograd import Variable
import matplotlib.pyplot as plt

RESULT_PATH = './model_results/'

# %%
# PARAMETERS FOR 
LAMBDA_PEN = 1000
L_BOUND = -10
U_BOUND = 10
N_POINTS = 512

NUM_EPOCHS = 15000

M_POINTS = 10
ALPHA = 2

SELECTION_RATE = 0.2

DISCRETE_POINTS = np.linspace(L_BOUND, U_BOUND, N_POINTS)

# %%
class sinFn(torch.nn.Module):
    @staticmethod
    def forward(input):
        return torch.sin(input)

# %%
def model_on_interval(nn_model, discrete_points):
    x_vals = [torch.tensor([i], requires_grad=True, dtype=torch.float) for i in discrete_points]

    model_output = []
    for i in x_vals:
        model_output.append(nn_model(i).detach().numpy().item())
    return model_output

# %%
epsilon_Loss_penalty(p_fn4, res1_21_sin[3], LAMBDA_PEN, U_BOUND, DISCRETE_POINTS)
# Out:
# (tensor([1.9435], grad_fn=<MulBackward0>),
#  tensor([1.9435], grad_fn=<AddBackward0>))

# %%
eig_val, ground_state = finite_diff_method(DISCRETE_POINTS, p_fn4)
print(eig_val[0])
plot_finite_diff_sol(eig_val, -ground_state, DISCRETE_POINTS, res1_21_sin[3])
# Out:
# 1.9424217990221013

# %%
class X_Square_sin:
    def __init__(self, const, use_sin=False):
        self.const = const
        if use_sin == True:
            self.sin_const = np.random.choice(np.arange(10, 50))
        
    def forward(self, x):
        return x**2 + self.const + self.sin_const*math.sin(x)
    
class Potential_Function:
    def __init__(self, c_0=0,
                 M_points=M_POINTS,
                 L_endpoint=U_BOUND, 
                 alpha=ALPHA, 
                 rescale=1):
        self.M_points = M_points
        self.L_endpoint = L_endpoint
        self.alpha = alpha
        self.c_0 = c_0
        self.rescale = 1
        self.is_updated = False
        
        self.ti_list = np.random.normal(loc=0, scale=1.0, size= self.M_points)
        self.ci_list = []
        for i in range(1, self.M_points+1):
            c_i = self.L_endpoint/(i * math.pi)
            c_i = (c_i)**self.alpha
            self.ci_list.append(c_i)
                        
        
    def forward(self, x):
        """
        V(x) = rescale * (c_0 + SUM(...))
        
        """
        f_value = 0
        summation = 0
        
        #Iterative method:

        for i in range(1, self.M_points+1):
            cos_val = np.cos((i * math.pi * x)/self.L_endpoint)
            summation += self.ti_list[i-1] * self.ci_list[i-1] * cos_val

        f_value += summation
        f_value += self.c_0
        return self.rescale * f_value
    
    def set_c0_value(self, val):
        self.c_0 = val
        return
    
    def set_rescale_factor(self, val):
        self.rescale = val
        return 
    
    def plot_function(self, discrete_points):
        y_values = [self.forward(i) for i in discrete_points]
        plt.plot(discrete_points, y_values)
    
    def update_potential_fn(self, discrete_points):
        if self.is_updated == True:
            raise Exception("Potential Function is updated")
        else:
            # (1) Check lowest value to set appropriate c_0 value:
            min_val = min([self.forward(i) for i in discrete_points])
            print("Original min val = " + str(min_val))

            # (2) Set c_0 value s.t. every value in y_values is > 0: 
            if min_val < 0:
                c_0 = math.ceil(abs(min_val))
                self.set_c0_value(c_0)
                new_y = [self.forward(i) for i in discrete_points]
                print("Min val with c_0 updated = " + str(min(new_y)))
            
            # (3) Rescale potential function s.t. every value lies between 0 and 5:
            new_y = [self.forward(i) for i in discrete_points]
            max_v = max(new_y)
            rescale = 5/max_v
            self.set_rescale_factor(rescale)
        
            # (4) Update c_0 one more time to ensure min_val > 1:
            new_y = [self.forward(i) for i in discrete_points]
            min_val = min(new_y)
            if min_val < 0:
                raise Exception("bug: min val can't be < 0 at this point")
            
            if min_val >= 0 and min_val < 1:
                new_c0 = self.c_0 + 1/rescale
                self.set_c0_value(new_c0)
                
            final_y = [self.forward(i) for i in discrete_points]
            min_val = min(final_y)
            max_val = max(final_y)
            print("Final min and max vals are {}, {}".format(min_val, max_val))
            self.is_updated = True
        return

# %%
def epsilon_Loss_penalty(v_x, model_u, 
                         lambda_pen,
                         upper_bound, 
                         discrete_points):
    eps_sum = 0
    pen = 0

    h = (2*upper_bound)/(len(discrete_points)-1)
#     print("h = "+ str(h))
    for i in discrete_points:
        x_i = torch.tensor([i], requires_grad=True, dtype=torch.float)

        u_prime_square = torch.square(model_u.u_prime(x_i))
        u_xi_square = torch.square(model_u(x_i))
        
        v_xi = v_x.forward(i)
        if v_xi < 0:
            raise ValueError('Potential Function value is < 0')

        t = u_prime_square + v_xi*u_xi_square
        eps_sum += t
        
        pen+= u_xi_square
        
    epsilon_fn = h*eps_sum
    
    penalty = lambda_pen * torch.square(h*pen-1)
#     print("epsilon_fn value = " + str(epsilon_fn))
#     print("penalty value = " + str(penalty))
    return (epsilon_fn, epsilon_fn + penalty)

# %%
# CREATING MODEL CLASS
class Nonlinear_1(nn.Module):
    """
    Neural Network with 1 layers
    """
    def __init__(self, layer_width, use_sin=False):
        super(Nonlinear_1, self).__init__()
        self.sigmoid = nn.Sigmoid()
        self.sin = sinFn()
        self.use_sin = use_sin
#         self.tanh = nn.Tanh()

        self.hidden = nn.Linear(1, layer_width)
        self.output = nn.Linear(layer_width, 1)

            
    def forward(self, x):
        if self.use_sin == True:
            x = self.hidden(x)
            x = self.sin(x)
            x = self.output(x)
        else:
            x = self.hidden(x)
            x = self.sigmoid(x)
            x = self.output(x)
        return x

    def normalize_model(self, discrete_points):
        """
        GOAL: Normalize the output weight layer
        model.output *= c
        where,
        scalar c = 1/denom
        """
        
        h = discrete_points[1]-discrete_points[0]
        s = 0
        for i in discrete_points:
            x_i = torch.tensor([i], requires_grad=True, dtype=torch.float)
            s += self(x_i)**2
        denom = math.sqrt(h) * torch.sqrt(s)
        c = 1/denom

        print("Before normalization: ")
        print(self.output.weight.data)
        print(self.output.bias.data)
        
        self.output.weight.data.copy_(c.item() * self.output.weight.data)
        self.output.bias.data.copy_(c.item() * self.output.bias.data)

        print("After normalization: ")
        print(self.output.weight.data)
        print(self.output.bias.data)
        print("c value = " + str(c))

        return 

    def u_prime(self, x_in):
        y = self(x_in)
        y_prime = torch.autograd.grad(y.sum(), x_in, create_graph=True)
        return y_prime[0]

# %%
class Nonlinear_2(nn.Module):
    """
    Neural Network with 2 layers
    """
    def __init__(self, layer_width, use_sin=False):
        super(Nonlinear_2, self).__init__()
        
        self.sigmoid = nn.Sigmoid()
        self.sin = sinFn()
#         self.tanh = nn.Tanh()
        self.use_sin = use_sin
        
        self.hidden1 = nn.Linear(1, layer_width)
        self.hidden2 = nn.Linear(layer_width, layer_width)
        self.output = nn.Linear(layer_width, 1)
        
    def forward(self, x):
        if self.use_sin == True:
            x = self.hidden1(x)
            x = self.sin(x)
            
            x = self.hidden2(x)
            x = self.sin(x)
            
            x = self.output(x)
            
        else:
            x = self.hidden1(x)
            x = self.sigmoid(x)
            
            x = self.hidden2(x)
            x = self.sigmoid(x)
            
            x = self.output(x)
        return x

    def normalize_model(self, discrete_points):
        """
        GOAL: Normalize the output weight layer
        model.output *= c
        where,
        scalar c = 1/denom
        """
        
        h = discrete_points[1]-discrete_points[0]
        s = 0
        for i in discrete_points:
            x_i = torch.tensor([i], requires_grad=True, dtype=torch.float)
            s += self(x_i)**2
        denom = math.sqrt(h) * torch.sqrt(s)
        c = 1/denom

        print("Before normalization: ")
        print(self.output.weight.data)
        print(self.output.bias.data)
        
        self.output.weight.data.copy_(c.item() * self.output.weight.data)
        self.output.bias.data.copy_(c.item() * self.output.bias.data)

        print("After normalization: ")
        print(self.output.weight.data)
        print(self.output.bias.data)
        print("c value = " + str(c))

        return 

    def u_prime(self, x_in):
        y = self(x_in)
        y_prime = torch.autograd.grad(y.sum(), x_in, create_graph=True)
        return y_prime[0]

# %%
# TRANING MODEL
def batch_train_with_penalty(model, 
                         num_epochs, 
                         v_x, 
                         optimizer, 
                         lambda_pen, 
                         discrete_points):
    # For plotting loss value over epochs:
    x_epochs = []
    y_loss = []
    y_loss_pen = []

    #Early stopping criteria:
    last_min_loss = 0
    min_delta = 1e-3 #minimum difference to be considered better loss
    best_model = None
    
    now = datetime.datetime.now(tz=timezone('US/Eastern'))
    print("Start time is " + str(now))
    start = time.time()

    for epoch in range(num_epochs):
        optimizer.zero_grad()
        loss, loss_pen = epsilon_Loss_penalty(v_x, model, lambda_pen,
                                    U_BOUND, discrete_points)

        y_loss_pen.append(loss_pen.detach().numpy().item())
        y_loss.append(loss.detach().numpy().item())
        x_epochs.append(epoch)
        
        if epoch == 0:
            print("Initiate first min loss = " + str(loss_pen))
            best_model = copy.deepcopy(model)
            last_min_loss = loss_pen
        
        # Save best model
        if loss_pen < last_min_loss and abs(loss_pen-last_min_loss) >= min_delta:
            print("New min loss = " + str(loss_pen))
            best_model = copy.deepcopy(model)
            last_min_loss = loss_pen

        if epoch % 100 == 0 or (epoch+1)%100 == 0:
            print('epoch {}, loss with penalty {}'.format(epoch, loss_pen.item()))
        loss_pen.backward()
        optimizer.step()
        
    end = time.time()
    time1 = end-start
    print("Using potential function defined as class takes " + str(time1))

    model.normalize_model(DISCRETE_POINTS)
    best_model.normalize_model(DISCRETE_POINTS)
    return (x_epochs, y_loss, y_loss_pen, best_model)


def minibatch_train_with_penalty(model, 
                               num_epochs, 
                               v_x, 
                               optimizer, 
                               lambda_pen,
                               discrete_points,
                               batch_size=32):
    # For plotting loss value over epochs:
    x_epochs = []
    y_loss = []
    y_loss_pen = []
    
    #Early stopping criteria:
    last_min_loss = 0
    min_delta = 1e-3 #minimum difference to be considered better loss
    best_model = None

    m = len(discrete_points)
    num_batches = int(m/batch_size)
#         print("Number of batches " + str(num_batches))
    
    now = datetime.datetime.now(tz=timezone('US/Eastern'))
    print("Start time is " + str(now))
    start = time.time()



    for epoch in range(num_epochs):
        perm = torch.randperm(m)
        avg_loss_pen = 0
        avg_loss = 0
        
        for i in range(0, m, batch_size):
            optimizer.zero_grad()

            indices = perm[i: i+batch_size]

            loss, loss_pen = epsilon_Loss_penalty(v_x, model, 
                                                  lambda_pen,
                                                  U_BOUND, 
                                                  discrete_points[indices])
            
            if epoch == 0 and i == 0:
                print("Initiate first min loss = " + str(loss_pen))
                best_model = copy.deepcopy(model)
                last_min_loss = loss_pen
                
            avg_loss_pen += loss_pen.item()
            avg_loss += loss.item()
            
            # Save best model
            if loss_pen < last_min_loss and abs(loss_pen-last_min_loss) >= min_delta:
                print("New min loss = " + str(loss_pen))
                best_model = copy.deepcopy(model)
                last_min_loss = loss_pen
            
            loss_pen.backward()
            optimizer.step()

        avg_loss_pen = avg_loss_pen/num_batches
        avg_loss = avg_loss/num_batches

        y_loss_pen.append(avg_loss_pen)
        y_loss.append(avg_loss)
        x_epochs.append(epoch)
        
        if epoch % 100 == 0 or (epoch+1)%100 == 0:
            print('epoch {}, loss with penalty {}'.format(epoch, avg_loss_pen))
    
    end = time.time()
    time1 = end-start
    print("Using potential function defined as class takes " + str(time1))
    
    model.normalize_model(DISCRETE_POINTS)
    best_model.normalize_model(DISCRETE_POINTS)
    return (x_epochs, y_loss, y_loss_pen, best_model)

# %%
pfn_list = ['p_fn1', 'p_fn2', 'p_fn3', 'p_fn4', 'p_fn5']

# %%
p_fn_fnames = {p_fn1: 'p_fn1',
               p_fn2: 'p_fn2',
               p_fn3: 'p_fn3',
               p_fn4: 'p_fn4',
               p_fn5: 'p_fn5'}
model_1_1_sin_info = {'model_fname': 'model_1_1_sin'}
model_1_1_sigmoid= 'model_1_1_sigmoid'

# %%
def save_pfn(res_path, p_fn_dict: dict):
    """
    Save a dict of p_fn as fixed files, 
    when need to train p_fn, just load these p_fn saved files. 
    """
    for p in p_fn_dict:
        p_fn_fpath = res_path + p_fn_dict[p]
        with open(p_fn_fpath, "wb") as fp:
            pickle.dump(p, fp)
    return

def load_pfn(p_fn_fpath: str):
    # TODO
    with open(p_fn_fpath, "rb") as fp:
        p_fn = pickle.load(fp)
    return p_fn

def load_model(load_model, f_path):
    return load_model.load_state_dict(torch.load(f_path))
    
def auto_test_documentation(model, optimizer, p_fn, 
                            model_name: str, res_path: str,
                            loss_fname: str, loss_with_pen_fname: str):
    """
    Automate training model, then save its results for future reference. 
    
    """
    loss_fpath = res_path + loss_fname
    loss_with_pen_fpath = res_path + loss_with_pen_fname
    model_fpath = res_path + model_name
    x_epochs, y_loss, y_loss_pen, best_model = batch_train_with_penalty(model, 
                                                                        NUM_EPOCHS, 
                                                                        p_fn, 
                                                                        optimizer, 
                                                                        LAMBDA_PEN, 
                                                                        DISCRETE_POINTS)
    
    #: store loss & loss with penalty value in a file type
    with open(loss_fpath, "wb") as fp:
        pickle.dump(y_loss, fp) #use: with open() as fp: pickle.load(fp) to load file
    
    with open(loss_with_pen_fpath, "wb") as fp:
        pickle.dump(y_loss_pen, fp)
        
    #: store best_model from training
    torch.save(best_model.state_dict(), model_fpath)
    
    ### How to load model from saved file
    # load_model = MODEL_CLASS(...)
    # load_model.load_state_dict(torch.load(f_path))
    ###
    
    #: store eigenvalue + corresponding eigenfunction using FD method
#     eig_val, ground_state = finite_diff_method(DISCRETE_POINTS, p_fn)
#     with open(eig_val_fpath, "wb") as fp:
#         pickle.dump(l, fp)
        
#     with open(ground_state_fpath, "rb") as fp:
#         pickle.dump(l, fp)
        
    return x_epochs, y_loss, y_loss_pen, best_model

# %%
# PLOT DATA
def plot_figure(x_val, y_val, x_test=None, predicted=None, log_scale=False):
    plt.clf()
    plt.figure(figsize=(8, 6), dpi=80)
    if log_scale==True:
        plt.yscale('log')
    plt.plot(x_val, y_val, '--', label='True data', alpha=0.5)
    if predicted != None:
        plt.plot(x_test, predicted, '--', label='Predictions', alpha=0.5)
    plt.legend(loc='best')
    plt.show()

# %%
del model_11_sin
del model_11_sigmoid

del adam_opt_11_sin
del adam_opt_11_sigmoid

del model_21_sin
del model_21_sigmoid

del adam_opt_21_sin
del adam_opt_21_sigmoid

# %%
learningRate = 0.008

#INIT Nonlinear 1 MODELS
model_11_sin = Nonlinear_1(20, use_sin=True)
model_11_sigmoid = Nonlinear_1(20)

if torch.cuda.is_available():
    model_11_sin.cuda()
    model_11_sigmoid.cuda()

# INIT OPTIMIZER CLASS
# Adam:
adam_opt_11_sin = torch.optim.Adam(model_11_sin.parameters(), 
                                    lr=learningRate, 
                                    betas=(0.9, 0.999), 
                                    eps=1e-08, 
                                    weight_decay=0, 
                                    amsgrad=False)

adam_opt_11_sigmoid = torch.optim.Adam(model_11_sigmoid.parameters(), 
                                    lr=learningRate, 
                                    betas=(0.9, 0.999), 
                                    eps=1e-08, 
                                    weight_decay=0, 
                                    amsgrad=False)

# %%
#INIT Nonlinear 2 MODELS
model_21_sin = Nonlinear_2(layer_width=60, use_sin=True)
model_21_sigmoid = Nonlinear_2(layer_width=20)

# INIT OPTIMIZER CLASS
# Adam:
adam_opt_21_sin = torch.optim.Adam(model_21_sin.parameters(), 
                                    lr=learningRate, 
                                    betas=(0.9, 0.999), 
                                    eps=1e-08, 
                                    weight_decay=0, 
                                    amsgrad=False)

adam_opt_21_sigmoid = torch.optim.Adam(model_21_sigmoid.parameters(), 
                                    lr=learningRate, 
                                    betas=(0.9, 0.999), 
                                    eps=1e-08, 
                                    weight_decay=0, 
                                    amsgrad=False)

# %% [raw]
# p_fn1 = load_pfn(RESULT_PATH+'p_fn1')
# p_fn2 = load_pfn(RESULT_PATH+'p_fn2')
# p_fn3 = load_pfn(RESULT_PATH+'p_fn3')
# p_fn4 = load_pfn(RESULT_PATH+'p_fn4')
#
# p_fn5 = load_pfn(RESULT_PATH+'p_fn5')
# p_fn6 = load_pfn(RESULT_PATH+'p_fn6')
# p_fn7 = load_pfn(RESULT_PATH+'p_fn7')
# p_fn8 = load_pfn(RESULT_PATH+'p_fn8')

# %%
eig_val, ground_state = finite_diff_method(DISCRETE_POINTS, p_fn6)
print(eig_val[0])
plot_finite_diff_sol(eig_val, -ground_state, DISCRETE_POINTS)

eig_val, ground_state = finite_diff_method(DISCRETE_POINTS, p_fn7)
print(eig_val[0])
plot_finite_diff_sol(eig_val, -ground_state, DISCRETE_POINTS)

eig_val, ground_state = finite_diff_method(DISCRETE_POINTS, p_fn8)
print(eig_val[0])
plot_finite_diff_sol(eig_val, -ground_state, DISCRETE_POINTS)

eig_val, ground_state = finite_diff_method(DISCRETE_POINTS, p_fn9)
print(eig_val[0])
plot_finite_diff_sol(eig_val, -ground_state, DISCRETE_POINTS)

# eig_val, ground_state = finite_diff_method(DISCRETE_POINTS, p_fn5)
# print(eig_val[0])
# plot_finite_diff_sol(eig_val, -ground_state, DISCRETE_POINTS)
# Out:
# 1.4934874855130147
# 1.4336003452293382
# 1.5404300575638281
# 1.3914413287146994

# %%
eig_val, ground_state = finite_diff_method(DISCRETE_POINTS, p_fn1)
print(eig_val[0])
plot_finite_diff_sol(eig_val, -ground_state, DISCRETE_POINTS)

eig_val, ground_state = finite_diff_method(DISCRETE_POINTS, p_fn2)
print(eig_val[0])
plot_finite_diff_sol(eig_val, -ground_state, DISCRETE_POINTS)

eig_val, ground_state = finite_diff_method(DISCRETE_POINTS, p_fn3)
print(eig_val[0])
plot_finite_diff_sol(eig_val, -ground_state, DISCRETE_POINTS)

eig_val, ground_state = finite_diff_method(DISCRETE_POINTS, p_fn4)
print(eig_val[0])
plot_finite_diff_sol(eig_val, -ground_state, DISCRETE_POINTS)

eig_val, ground_state = finite_diff_method(DISCRETE_POINTS, p_fn5)
print(eig_val[0])
plot_finite_diff_sol(eig_val, -ground_state, DISCRETE_POINTS)
# Out:
# 2.2998316982551303
# 1.3325153410653177
# 2.6426317029490844
# 1.9424217990221013
# 1.3693588912383812

# %% [markdown]
# ### Models with 1 layer, layer width = 50, sin() activation

# %%
del model_11_sin
del adam_opt_11_sin

model_11_sin = Nonlinear_1(50, use_sin=True)
adam_opt_11_sin = torch.optim.Adam(model_11_sin.parameters(), 
                                    lr=learningRate, 
                                    betas=(0.9, 0.999), 
                                    eps=1e-08, 
                                    weight_decay=0, 
                                    amsgrad=False)


res1_11_sin = auto_test_documentation(model_11_sin, adam_opt_11_sin, p_fn1, 
                                      model_name='model_11_sin_pfn1',
                                      res_path=RESULT_PATH,
                                      loss_fname='loss_11_sin_pfn1',
                                      loss_with_pen_fname = 'loss_pen_11_sin_pfn1')
# Out:
# Start time is 2022-08-10 14:31:25.496207-04:00
# Initiate first min loss = tensor([803.7723], grad_fn=<AddBackward0>)
# epoch 0, loss with penalty 803.7722778320312
# New min loss = tensor([10.2055], grad_fn=<AddBackward0>)
# New min loss = tensor([4.8059], grad_fn=<AddBackward0>)
# New min loss = tensor([4.3260], grad_fn=<AddBackward0>)
# New min loss = tensor([4.1379], grad_fn=<AddBackward0>)
# New min loss = tensor([4.1000], grad_fn=<AddBackward0>)
# New min loss = tensor([3.9947], grad_fn=<AddBackward0>)
# New min loss = tensor([3.9228], grad_fn=<AddBackward0>)
# New min loss = tensor([3.8896], grad_fn=<AddBackward0>)
# New min loss = tensor([3.8825], grad_fn=<AddBackward0>)
# New min loss = tensor([3.8806], grad_fn=<AddBackward0>)
# New min loss = tensor([3.8140], grad_fn=<AddBackward0>)
# New min loss = tensor([3.8118], grad_fn=<AddBackward0>)
# New min loss = tensor([3.7850], grad_fn=<AddBackward0>)
# New min loss = tensor([3.7455], grad_fn=<AddBackward0>)
# New min loss = tensor([3.7273], grad_fn=<AddBackward0>)
# New min loss = tensor([3.7133], grad_fn=<AddBackward0>)
# New min loss = tensor([3.7063], grad_fn=<AddBackward0>)
# New min loss = tensor([3.6764], grad_fn=<AddBackward0>)
# New min loss = tensor([3.6482], grad_fn=<AddBackward0>)
# New min loss = tensor([3.6464], grad_fn=<AddBackward0>)
# New min loss = tensor([3.6209], grad_fn=<AddBackward0>)
# New min loss = tensor([3.6111], grad_fn=<AddBackward0>)
# New min loss = tensor([3.5937], grad_fn=<AddBackward0>)
# New min loss = tensor([3.5790], grad_fn=<AddBackward0>)
# New min loss = tensor([3.5640], grad_fn=<AddBackward0>)
# New min loss = tensor([3.5489], grad_fn=<AddBackward0>)
# New min loss = tensor([3.5460], grad_fn=<AddBackward0>)
# New min loss = tensor([3.5348], grad_fn=<AddBackward0>)
# New min loss = tensor([3.5197], grad_fn=<AddBackward0>)
# New min loss = tensor([3.5143], grad_fn=<AddBackward0>)
# New min loss = tensor([3.5043], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4906], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4844], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4748], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4619], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4546], grad_fn=<AddBackward0>)
# epoch 99, loss with penalty 3.4546220302581787
# New min loss = tensor([3.4449], grad_fn=<AddBackward0>)
# epoch 100, loss with penalty 3.444941282272339
# New min loss = tensor([3.4333], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4259], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4160], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4049], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3970], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3870], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3769], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3688], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3587], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3490], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3405], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3305], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3215], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3127], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3029], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2941], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2850], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2756], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2670], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2577], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2486], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2399], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2306], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2220], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2131], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2041], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1954], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1865], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1778], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1692], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1604], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1518], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1432], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1346], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1261], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1175], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1091], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1007], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0923], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0840], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0756], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0674], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0591], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0509], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0428], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0347], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0266], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0186], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0106], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0027], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9948], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9870], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9792], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9715], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9638], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9561], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9486], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9410], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9336], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9261], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9188], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9114], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9042], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8970], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8898], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8827], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8757], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8688], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8618], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8550], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8482], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8415], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8348], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8282], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8217], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8152], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8088], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8024], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7962], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7899], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7838], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7777], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7717], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7657], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7598], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7540], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7483], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7426], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7370], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7314], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7259], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7205], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7152], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7099], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7046], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6995], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6944], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6894], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6844], grad_fn=<AddBackward0>)
# epoch 199, loss with penalty 2.6844475269317627
# New min loss = tensor([2.6796], grad_fn=<AddBackward0>)
# epoch 200, loss with penalty 2.67956280708313
# New min loss = tensor([2.6747], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6700], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6653], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6607], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6561], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6516], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6472], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6428], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6385], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6343], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6301], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6260], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6219], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6179], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6140], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6101], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6063], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6025], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5988], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5952], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5916], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5881], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5846], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5812], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5778], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5745], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5712], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5680], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5649], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5618], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5587], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5557], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5528], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5499], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5470], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5442], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5414], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5387], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5360], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5334], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5308], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5283], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5258], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5234], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5210], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5186], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5163], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5140], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5117], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5095], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5073], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5052], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5031], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5011], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4990], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4971], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4951], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4932], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4913], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4894], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4876], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4858], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4841], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4824], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4807], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4790], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4774], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4758], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4742], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4726], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4711], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4696], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4682], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4667], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4653], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4639], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4625], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4612], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4599], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4586], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4573], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4561], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4549], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4537], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4525], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4513], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4502], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4490], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4479], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4469], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4458], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4448], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4437], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4427], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4408], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4389], grad_fn=<AddBackward0>)
# epoch 299, loss with penalty 2.4379756450653076
# New min loss = tensor([2.4371], grad_fn=<AddBackward0>)
# epoch 300, loss with penalty 2.4370739459991455
# New min loss = tensor([2.4353], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4336], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4320], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4304], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4289], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4274], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4260], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4246], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4233], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4220], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4208], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4196], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4185], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4174], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4163], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4153], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4138], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4124], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4111], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4098], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4086], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4074], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4063], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4053], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4040], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4028], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4016], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4005], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3995], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3983], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3972], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3962], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3951], grad_fn=<AddBackward0>)
# epoch 399, loss with penalty 2.3947560787200928
# epoch 400, loss with penalty 2.3945834636688232
# New min loss = tensor([2.3941], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3930], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3920], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3909], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3899], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3888], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3878], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3868], grad_fn=<AddBackward0>)
# epoch 499, loss with penalty 2.468291759490967
# epoch 500, loss with penalty 3.967599630355835
# epoch 599, loss with penalty 2.3951833248138428
# epoch 600, loss with penalty 2.3950576782226562
# epoch 699, loss with penalty 2.387476921081543
# epoch 700, loss with penalty 2.3874213695526123
# epoch 799, loss with penalty 2.424600124359131
# epoch 800, loss with penalty 2.405442237854004
# epoch 899, loss with penalty 2.391409158706665
# epoch 900, loss with penalty 2.39133620262146
# epoch 999, loss with penalty 2.640953302383423
# epoch 1000, loss with penalty 2.8320956230163574

# %%
del model_11_sin
del adam_opt_11_sin

model_11_sin = Nonlinear_1(50, use_sin=True)
adam_opt_11_sin = torch.optim.Adam(model_11_sin.parameters(), 
                                    lr=learningRate, 
                                    betas=(0.9, 0.999), 
                                    eps=1e-08, 
                                    weight_decay=0, 
                                    amsgrad=False)


res2_11_sin = auto_test_documentation(model_11_sin, adam_opt_11_sin, p_fn2, 
                                      model_name='model_11_sin_pfn2',
                                      res_path=RESULT_PATH,
                                      loss_fname='loss_11_sin_pfn2',
                                      loss_with_pen_fname = 'loss_pen_11_sin_pfn2')

# %%
del model_11_sin
del adam_opt_11_sin

model_11_sin = Nonlinear_1(50, use_sin=True)
adam_opt_11_sin = torch.optim.Adam(model_11_sin.parameters(), 
                                    lr=learningRate, 
                                    betas=(0.9, 0.999), 
                                    eps=1e-08, 
                                    weight_decay=0, 
                                    amsgrad=False)


res3_11_sin = auto_test_documentation(model_11_sin, adam_opt_11_sin, p_fn3, 
                                      model_name='model_11_sin_pfn3',
                                      res_path=RESULT_PATH,
                                      loss_fname='loss_11_sin_pfn3',
                                      loss_with_pen_fname = 'loss_pen_11_sin_pfn3')

# %%
del model_11_sin
del adam_opt_11_sin

model_11_sin = Nonlinear_1(50, use_sin=True)
adam_opt_11_sin = torch.optim.Adam(model_11_sin.parameters(), 
                                    lr=learningRate, 
                                    betas=(0.9, 0.999), 
                                    eps=1e-08, 
                                    weight_decay=0, 
                                    amsgrad=False)


res4_11_sin = auto_test_documentation(model_11_sin, adam_opt_11_sin, p_fn4, 
                                      model_name='model_11_sin_pfn4',
                                      res_path=RESULT_PATH,
                                      loss_fname='loss_11_sin_pfn4',
                                      loss_with_pen_fname = 'loss_pen_11_sin_pfn4')

# %%
del model_11_sin
del adam_opt_11_sin

model_11_sin = Nonlinear_1(50, use_sin=True)
adam_opt_11_sin = torch.optim.Adam(model_11_sin.parameters(), 
                                    lr=learningRate, 
                                    betas=(0.9, 0.999), 
                                    eps=1e-08, 
                                    weight_decay=0, 
                                    amsgrad=False)


res5_11_sin = auto_test_documentation(model_11_sin, adam_opt_11_sin, p_fn5, 
                                      model_name='model_11_sin_pfn5',
                                      res_path=RESULT_PATH,
                                      loss_fname='loss_11_sin_pfn5',
                                      loss_with_pen_fname = 'loss_pen_11_sin_pfn5')

# %%
del model_11_sin
del adam_opt_11_sin

model_11_sin = Nonlinear_1(50, use_sin=True)
adam_opt_11_sin = torch.optim.Adam(model_11_sin.parameters(), 
                                    lr=learningRate, 
                                    betas=(0.9, 0.999), 
                                    eps=1e-08, 
                                    weight_decay=0, 
                                    amsgrad=False)


res6_11_sin = auto_test_documentation(model_11_sin, adam_opt_11_sin, p_fn6, 
                                      model_name='model_11_sin_pfn6',
                                      res_path=RESULT_PATH,
                                      loss_fname='loss_11_sin_pfn6',
                                      loss_with_pen_fname = 'loss_pen_11_sin_pfn6')

# %%
del model_11_sin
del adam_opt_11_sin

model_11_sin = Nonlinear_1(50, use_sin=True)
adam_opt_11_sin = torch.optim.Adam(model_11_sin.parameters(), 
                                    lr=learningRate, 
                                    betas=(0.9, 0.999), 
                                    eps=1e-08, 
                                    weight_decay=0, 
                                    amsgrad=False)


res7_11_sin = auto_test_documentation(model_11_sin, adam_opt_11_sin, p_fn7, 
                                      model_name='model_11_sin_pfn7',
                                      res_path=RESULT_PATH,
                                      loss_fname='loss_11_sin_pfn7',
                                      loss_with_pen_fname = 'loss_pen_11_sin_pfn7')

# %%
del model_11_sin
del adam_opt_11_sin

model_11_sin = Nonlinear_1(50, use_sin=True)
adam_opt_11_sin = torch.optim.Adam(model_11_sin.parameters(), 
                                    lr=learningRate, 
                                    betas=(0.9, 0.999), 
                                    eps=1e-08, 
                                    weight_decay=0, 
                                    amsgrad=False)


res8_11_sin = auto_test_documentation(model_11_sin, adam_opt_11_sin, p_fn8, 
                                      model_name='model_11_sin_pfn8',
                                      res_path=RESULT_PATH,
                                      loss_fname='loss_11_sin_pfn8',
                                      loss_with_pen_fname = 'loss_pen_11_sin_pfn8')

# %% [markdown]
# ### Models with 2 layers, layer width = 60, sin() activation

# %%
del model_21_sin
del adam_opt_21_sin

model_21_sin = Nonlinear_2(layer_width=60, use_sin=True)
adam_opt_21_sin = torch.optim.Adam(model_21_sin.parameters(), 
                                    lr=learningRate, 
                                    betas=(0.9, 0.999), 
                                    eps=1e-08, 
                                    weight_decay=0, 
                                    amsgrad=False)

res1_21_sin = auto_test_documentation(model_21_sin, adam_opt_21_sin, p_fn1, 
                                      model_name='model_21_sin_pfn1',
                                      res_path=RESULT_PATH,
                                      loss_fname='loss_21_sin_pfn1',
                                      loss_with_pen_fname = 'loss_pen_21_sin_pfn1')
# Out:
# Start time is 2022-08-09 23:25:17.098908-04:00
# Initiate first min loss = tensor([369.7161], grad_fn=<AddBackward0>)
# epoch 0, loss with penalty 369.71612548828125
# New min loss = tensor([72.7630], grad_fn=<AddBackward0>)
# New min loss = tensor([3.8704], grad_fn=<AddBackward0>)
# New min loss = tensor([3.8276], grad_fn=<AddBackward0>)
# New min loss = tensor([3.6663], grad_fn=<AddBackward0>)
# New min loss = tensor([3.6648], grad_fn=<AddBackward0>)
# New min loss = tensor([3.6521], grad_fn=<AddBackward0>)
# New min loss = tensor([3.6068], grad_fn=<AddBackward0>)
# New min loss = tensor([3.5925], grad_fn=<AddBackward0>)
# New min loss = tensor([3.5796], grad_fn=<AddBackward0>)
# New min loss = tensor([3.5677], grad_fn=<AddBackward0>)
# New min loss = tensor([3.5597], grad_fn=<AddBackward0>)
# New min loss = tensor([3.5554], grad_fn=<AddBackward0>)
# epoch 99, loss with penalty 3.568258047103882
# epoch 100, loss with penalty 3.5783181190490723
# New min loss = tensor([3.5428], grad_fn=<AddBackward0>)
# New min loss = tensor([3.5338], grad_fn=<AddBackward0>)
# New min loss = tensor([3.5285], grad_fn=<AddBackward0>)
# New min loss = tensor([3.5233], grad_fn=<AddBackward0>)
# New min loss = tensor([3.5171], grad_fn=<AddBackward0>)
# New min loss = tensor([3.5151], grad_fn=<AddBackward0>)
# New min loss = tensor([3.5109], grad_fn=<AddBackward0>)
# New min loss = tensor([3.5058], grad_fn=<AddBackward0>)
# New min loss = tensor([3.5023], grad_fn=<AddBackward0>)
# New min loss = tensor([3.5012], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4978], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4938], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4902], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4880], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4866], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4844], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4812], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4779], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4753], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4734], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4713], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4685], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4654], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4626], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4604], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4581], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4555], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4526], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4499], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4474], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4450], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4425], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4397], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4369], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4344], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4319], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4293], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4266], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4239], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4212], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4187], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4161], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4134], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4106], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4080], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4054], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4027], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4000], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3973], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3946], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3920], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3893], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3866], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3838], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3811], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3784], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3757], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3730], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3703], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3675], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3648], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3621], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3593], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3566], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3538], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3511], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3483], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3456], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3428], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3401], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3373], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3345], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3318], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3290], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3262], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3234], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3206], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3179], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3151], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3123], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3095], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3067], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3039], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3011], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2983], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2955], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2927], grad_fn=<AddBackward0>)
# epoch 199, loss with penalty 3.2926900386810303
# New min loss = tensor([3.2899], grad_fn=<AddBackward0>)
# epoch 200, loss with penalty 3.2898826599121094
# New min loss = tensor([3.2871], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2843], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2815], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2786], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2758], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2730], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2702], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2674], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2646], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2617], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2589], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2561], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2533], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2504], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2476], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2448], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2420], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2391], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2363], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2335], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2307], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2278], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2250], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2222], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2193], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2165], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2137], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2109], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2080], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2052], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2024], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1996], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1967], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1939], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1911], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1883], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1854], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1826], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1798], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1770], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1742], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1713], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1685], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1657], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1629], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1601], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1573], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1545], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1517], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1489], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1460], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1432], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1404], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1376], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1348], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1321], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1293], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1265], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1237], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1209], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1181], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1153], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1126], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1098], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1070], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1043], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1015], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0987], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0960], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0932], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0905], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0877], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0850], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0822], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0795], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0767], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0740], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0713], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0686], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0658], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0631], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0604], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0577], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0550], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0523], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0496], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0469], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0442], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0415], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0388], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0361], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0335], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0308], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0281], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0255], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0228], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0202], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0175], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0149], grad_fn=<AddBackward0>)
# epoch 299, loss with penalty 3.014873504638672
# New min loss = tensor([3.0122], grad_fn=<AddBackward0>)
# epoch 300, loss with penalty 3.0122344493865967
# New min loss = tensor([3.0096], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0070], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0043], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0017], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9991], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9965], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9939], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9913], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9887], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9861], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9835], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9810], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9784], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9758], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9733], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9707], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9681], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9656], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9631], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9605], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9580], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9555], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9530], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9504], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9479], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9454], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9429], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9405], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9380], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9355], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9330], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9306], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9281], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9257], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9232], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9208], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9183], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9159], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9135], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9111], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9087], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9063], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9039], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9015], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8991], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8967], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8943], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8920], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8896], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8873], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8849], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8826], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8803], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8779], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8756], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8733], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8710], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8687], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8664], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8641], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8619], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8596], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8573], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8551], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8528], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8506], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8484], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8461], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8439], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8417], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8395], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8373], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8351], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8329], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8307], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8286], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8264], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8243], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8221], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8200], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8178], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8157], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8136], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8115], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8094], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8073], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8052], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8031], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8010], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7989], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7969], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7948], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7928], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7907], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7887], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7867], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7847], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7827], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7807], grad_fn=<AddBackward0>)
# epoch 399, loss with penalty 2.780651569366455
# New min loss = tensor([2.7787], grad_fn=<AddBackward0>)
# epoch 400, loss with penalty 2.778656244277954
# New min loss = tensor([2.7767], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7747], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7727], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7707], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7688], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7668], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7649], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7630], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7610], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7591], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7572], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7553], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7534], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7515], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7496], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7477], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7459], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7440], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7421], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7403], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7384], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7366], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7348], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7330], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7312], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7294], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7276], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7258], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7240], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7222], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7204], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7187], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7169], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7152], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7135], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7117], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7100], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7083], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7066], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7049], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7032], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7015], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6998], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6981], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6965], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6948], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6932], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6915], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6899], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6883], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6866], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6850], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6834], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6818], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6802], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6786], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6770], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6755], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6739], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6723], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6708], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6693], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6677], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6662], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6647], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6631], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6616], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6601], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6586], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6572], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6557], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6542], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6527], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6513], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6498], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6484], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6469], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6455], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6441], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6426], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6412], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6398], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6384], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6370], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6356], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6343], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6329], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6315], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6302], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6288], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6275], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6261], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6248], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6235], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6221], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6208], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6195], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6182], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6169], grad_fn=<AddBackward0>)
# epoch 499, loss with penalty 2.616917371749878
# New min loss = tensor([2.6156], grad_fn=<AddBackward0>)
# epoch 500, loss with penalty 2.6156275272369385
# New min loss = tensor([2.6143], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6131], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6118], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6105], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6093], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6080], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6068], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6055], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6043], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6031], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6019], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6007], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5995], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5982], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5970], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5959], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5947], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5935], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5923], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5912], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5900], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5889], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5877], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5866], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5854], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5843], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5832], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5821], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5810], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5799], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5787], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5777], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5766], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5755], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5744], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5733], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5723], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5712], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5702], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5691], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5681], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5670], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5660], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5650], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5640], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5629], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5619], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5609], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5589], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5570], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5550], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5531], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5512], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5493], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5474], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5456], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5438], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5420], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5402], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5384], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5367], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5349], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5332], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5315], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5299], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5282], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5266], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5250], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5234], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5218], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5203], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5187], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5172], grad_fn=<AddBackward0>)
# epoch 599, loss with penalty 2.5164358615875244
# New min loss = tensor([2.5157], grad_fn=<AddBackward0>)
# epoch 600, loss with penalty 2.5156877040863037
# New min loss = tensor([2.5142], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5127], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5113], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5098], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5084], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5070], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5056], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5043], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5029], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5016], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5002], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4989], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4976], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4964], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4951], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4939], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4926], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4914], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4902], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4890], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4879], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4867], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4855], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4844], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4833], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4822], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4811], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4800], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4790], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4779], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4769], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4758], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4748], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4738], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4723], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4709], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4695], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4680], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4667], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4653], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4640], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4627], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4614], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4602], grad_fn=<AddBackward0>)
# epoch 699, loss with penalty 2.459751605987549
# epoch 700, loss with penalty 2.4593448638916016
# New min loss = tensor([2.4589], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4577], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4565], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4554], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4542], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4531], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4520], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4509], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4499], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4488], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4478], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4468], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4455], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4442], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4430], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4418], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4406], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4394], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4383], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4372], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4361], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4351], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4341], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4328], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4316], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4305], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4293], grad_fn=<AddBackward0>)
# epoch 799, loss with penalty 2.4290988445281982
# epoch 800, loss with penalty 2.428880214691162
# New min loss = tensor([2.4282], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4272], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4261], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4251], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4240], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4228], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4217], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4207], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4197], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4185], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4175], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4164], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4154], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4143], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4132], grad_fn=<AddBackward0>)
# epoch 899, loss with penalty 2.412339687347412
# New min loss = tensor([2.4122], grad_fn=<AddBackward0>)
# epoch 900, loss with penalty 2.4122142791748047
# New min loss = tensor([2.4111], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4101], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4090], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4079], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4069], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4059], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4048], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4038], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4027], grad_fn=<AddBackward0>)
# epoch 999, loss with penalty 2.4024851322174072
# epoch 1000, loss with penalty 2.402404546737671
# New min loss = tensor([2.4017], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4007], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3997], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3986], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3976], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3966], grad_fn=<AddBackward0>)
# epoch 1099, loss with penalty 2.395946741104126
# epoch 1100, loss with penalty 2.395892381668091
# New min loss = tensor([2.3956], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3945], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3935], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3925], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3915], grad_fn=<AddBackward0>)
# epoch 1199, loss with penalty 2.391003370285034
# epoch 1200, loss with penalty 2.3909595012664795
# New min loss = tensor([2.3905], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3894], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3884], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3874], grad_fn=<AddBackward0>)
# epoch 1299, loss with penalty 2.3868467807769775
# epoch 1300, loss with penalty 2.386806011199951
# New min loss = tensor([2.3864], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3853], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3843], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3833], grad_fn=<AddBackward0>)
# epoch 1399, loss with penalty 2.3830766677856445
# epoch 1400, loss with penalty 2.3830409049987793
# New min loss = tensor([2.3823], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3813], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3803], grad_fn=<AddBackward0>)
# epoch 1499, loss with penalty 2.379493474960327
# epoch 1500, loss with penalty 2.3794565200805664
# New min loss = tensor([2.3792], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3782], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3772], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3762], grad_fn=<AddBackward0>)
# epoch 1599, loss with penalty 2.3759658336639404
# epoch 1600, loss with penalty 2.375931978225708
# New min loss = tensor([2.3752], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3741], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3731], grad_fn=<AddBackward0>)
# epoch 1699, loss with penalty 2.372398853302002
# epoch 1700, loss with penalty 2.37235951423645
# New min loss = tensor([2.3721], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3711], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3701], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3690], grad_fn=<AddBackward0>)
# epoch 1799, loss with penalty 2.368699789047241
# epoch 1800, loss with penalty 2.3686623573303223
# New min loss = tensor([2.3680], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3670], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3660], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3650], grad_fn=<AddBackward0>)
# epoch 1899, loss with penalty 2.3647751808166504
# epoch 1900, loss with penalty 2.364733934402466
# New min loss = tensor([2.3640], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3629], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3619], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3609], grad_fn=<AddBackward0>)
# epoch 1999, loss with penalty 2.3604936599731445
# epoch 2000, loss with penalty 2.3604469299316406
# New min loss = tensor([2.3599], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3588], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3578], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3568], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3558], grad_fn=<AddBackward0>)
# epoch 2099, loss with penalty 2.3556876182556152
# epoch 2100, loss with penalty 2.35563588142395
# New min loss = tensor([2.3547], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3537], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3527], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3517], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3506], grad_fn=<AddBackward0>)
# epoch 2199, loss with penalty 2.350102663040161
# epoch 2200, loss with penalty 2.3500404357910156
# New min loss = tensor([2.3496], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3486], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3476], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3466], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3455], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3445], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3434], grad_fn=<AddBackward0>)
# epoch 2299, loss with penalty 2.3433752059936523
# epoch 2300, loss with penalty 2.343299150466919
# New min loss = tensor([2.3424], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3414], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3403], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3393], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3383], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3372], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3362], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3351], grad_fn=<AddBackward0>)
# epoch 2399, loss with penalty 2.335108518600464
# epoch 2400, loss with penalty 2.335019588470459
# New min loss = tensor([2.3341], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3331], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3320], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3310], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3299], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3288], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3277], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3267], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3257], grad_fn=<AddBackward0>)
# epoch 2499, loss with penalty 2.325382947921753
# epoch 2500, loss with penalty 2.325279951095581
# New min loss = tensor([2.3247], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3237], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3227], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3217], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3206], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3195], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3185], grad_fn=<AddBackward0>)
# epoch 2599, loss with penalty 3.6550979614257812
# epoch 2600, loss with penalty 4.209046363830566
# New min loss = tensor([2.3172], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3153], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3142], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3130], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3119], grad_fn=<AddBackward0>)
# epoch 2699, loss with penalty 2.311305522918701
# epoch 2700, loss with penalty 2.3112168312072754
# New min loss = tensor([2.3108], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3098], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3088], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3078], grad_fn=<AddBackward0>)
# epoch 2799, loss with penalty 2.3071064949035645
# epoch 2800, loss with penalty 2.307075262069702
# epoch 2899, loss with penalty 2.313260316848755
# epoch 2900, loss with penalty 2.3116116523742676
# New min loss = tensor([2.3067], grad_fn=<AddBackward0>)
# epoch 2999, loss with penalty 2.3061227798461914
# epoch 3000, loss with penalty 2.3060970306396484
# New min loss = tensor([2.3057], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3047], grad_fn=<AddBackward0>)
# epoch 3099, loss with penalty 2.3040051460266113
# epoch 3100, loss with penalty 2.3039891719818115
# New min loss = tensor([2.3037], grad_fn=<AddBackward0>)
# epoch 3199, loss with penalty 2.388368844985962
# epoch 3200, loss with penalty 2.3592114448547363
# epoch 3299, loss with penalty 2.306495189666748
# epoch 3300, loss with penalty 2.3064558506011963
# epoch 3399, loss with penalty 2.3037772178649902
# epoch 3400, loss with penalty 2.3037567138671875
# New min loss = tensor([2.3027], grad_fn=<AddBackward0>)
# epoch 3499, loss with penalty 2.3023688793182373
# epoch 3500, loss with penalty 2.3023576736450195
# epoch 3599, loss with penalty 2.5412936210632324
# epoch 3600, loss with penalty 2.333636999130249
# epoch 3699, loss with penalty 2.3050107955932617
# epoch 3700, loss with penalty 2.3049678802490234
# epoch 3799, loss with penalty 2.3026959896087646
# epoch 3800, loss with penalty 2.3026833534240723
# epoch 3899, loss with penalty 2.301727533340454
# epoch 3900, loss with penalty 2.3017210960388184
# New min loss = tensor([2.3017], grad_fn=<AddBackward0>)
# epoch 3999, loss with penalty 2.5548601150512695
# epoch 4000, loss with penalty 2.3846077919006348
# epoch 4099, loss with penalty 2.304069757461548
# epoch 4100, loss with penalty 2.30403733253479
# epoch 4199, loss with penalty 2.3022098541259766
# epoch 4200, loss with penalty 2.30220103263855
# epoch 4299, loss with penalty 2.301542282104492
# epoch 4300, loss with penalty 2.3015365600585938
# epoch 4399, loss with penalty 2.3741142749786377
# epoch 4400, loss with penalty 2.3239362239837646
# epoch 4499, loss with penalty 2.303102731704712
# epoch 4500, loss with penalty 2.3030858039855957
# epoch 4599, loss with penalty 2.301866292953491
# epoch 4600, loss with penalty 2.3018603324890137
# epoch 4699, loss with penalty 2.301443099975586
# epoch 4700, loss with penalty 2.3014416694641113
# epoch 4799, loss with penalty 2.3118293285369873
# epoch 4800, loss with penalty 2.3099071979522705
# epoch 4899, loss with penalty 2.3025522232055664
# epoch 4900, loss with penalty 2.3025400638580322
# epoch 4999, loss with penalty 2.301757574081421
# epoch 5000, loss with penalty 2.3017525672912598
# epoch 5099, loss with penalty 2.301870822906494
# epoch 5100, loss with penalty 2.3020896911621094
# epoch 5199, loss with penalty 2.3043856620788574
# epoch 5200, loss with penalty 2.3047032356262207
# epoch 5299, loss with penalty 2.3019773960113525
# epoch 5300, loss with penalty 2.301969528198242
# epoch 5399, loss with penalty 3.048180103302002
# epoch 5400, loss with penalty 3.5969414710998535
# epoch 5499, loss with penalty 2.3030784130096436
# epoch 5500, loss with penalty 2.302973508834839
# epoch 5599, loss with penalty 2.3018321990966797
# epoch 5600, loss with penalty 2.301826000213623
# epoch 5699, loss with penalty 2.3113691806793213
# epoch 5700, loss with penalty 2.3137154579162598
# epoch 5799, loss with penalty 2.3022518157958984
# epoch 5800, loss with penalty 2.302241086959839
# epoch 5899, loss with penalty 2.324370861053467
# epoch 5900, loss with penalty 2.5635595321655273
# epoch 5999, loss with penalty 2.3025543689727783
# epoch 6000, loss with penalty 2.3025360107421875
# epoch 6099, loss with penalty 2.7998852729797363
# epoch 6100, loss with penalty 2.500018835067749
# epoch 6199, loss with penalty 2.3026533126831055
# epoch 6200, loss with penalty 2.3026483058929443
# epoch 6299, loss with penalty 3.1254618167877197
# epoch 6300, loss with penalty 3.967564582824707
# epoch 6399, loss with penalty 2.3030292987823486
# epoch 6400, loss with penalty 2.3029792308807373
# epoch 6499, loss with penalty 2.6717092990875244
# epoch 6500, loss with penalty 2.9446332454681396
# epoch 6599, loss with penalty 2.3027188777923584
# epoch 6600, loss with penalty 2.3026976585388184
# epoch 6699, loss with penalty 2.308303117752075
# epoch 6700, loss with penalty 2.3164660930633545
# epoch 6799, loss with penalty 2.3161401748657227
# epoch 6800, loss with penalty 2.3620498180389404
# epoch 6899, loss with penalty 2.3630013465881348
# epoch 6900, loss with penalty 2.3253793716430664
# epoch 6999, loss with penalty 2.3342769145965576
# epoch 7000, loss with penalty 2.312190055847168
# epoch 7099, loss with penalty 2.3427510261535645
# epoch 7100, loss with penalty 2.3407413959503174
# epoch 7199, loss with penalty 2.30924129486084
# epoch 7200, loss with penalty 2.3103280067443848
# epoch 7299, loss with penalty 2.4190711975097656
# epoch 7300, loss with penalty 2.3940658569335938
# epoch 7399, loss with penalty 2.3060076236724854
# epoch 7400, loss with penalty 2.3052191734313965
# epoch 7499, loss with penalty 2.3022403717041016
# epoch 7500, loss with penalty 2.302558660507202
# epoch 7599, loss with penalty 2.3025290966033936
# epoch 7600, loss with penalty 2.3023197650909424
# epoch 7699, loss with penalty 2.323604106903076
# epoch 7700, loss with penalty 2.307269811630249
# epoch 7799, loss with penalty 2.3114004135131836
# epoch 7800, loss with penalty 2.314457893371582
# epoch 7899, loss with penalty 2.3612709045410156
# epoch 7900, loss with penalty 2.3400442600250244
# epoch 7999, loss with penalty 2.303375244140625
# epoch 8000, loss with penalty 2.3125174045562744
# epoch 8099, loss with penalty 2.3008620738983154
# epoch 8100, loss with penalty 2.300920248031616
# epoch 8199, loss with penalty 2.3274216651916504
# epoch 8200, loss with penalty 2.3161585330963135
# epoch 8299, loss with penalty 2.317049503326416
# epoch 8300, loss with penalty 2.312263250350952
# epoch 8399, loss with penalty 2.3147449493408203
# epoch 8400, loss with penalty 2.316673755645752
# New min loss = tensor([2.3006], grad_fn=<AddBackward0>)
# epoch 8499, loss with penalty 2.3005118370056152
# epoch 8500, loss with penalty 2.300616502761841
# epoch 8599, loss with penalty 2.337421178817749
# epoch 8600, loss with penalty 2.347264528274536
# epoch 8699, loss with penalty 2.450429677963257
# epoch 8700, loss with penalty 2.5101747512817383
# epoch 8799, loss with penalty 2.327465295791626
# epoch 8800, loss with penalty 2.3234856128692627
# epoch 8899, loss with penalty 2.304326295852661
# epoch 8900, loss with penalty 2.307464122772217
# epoch 8999, loss with penalty 2.310572624206543
# epoch 9000, loss with penalty 2.3115410804748535
# epoch 9099, loss with penalty 2.313958168029785
# epoch 9100, loss with penalty 2.306239366531372
# epoch 9199, loss with penalty 2.3018276691436768
# epoch 9200, loss with penalty 2.3016390800476074
# epoch 9299, loss with penalty 2.3031527996063232
# epoch 9300, loss with penalty 2.3046059608459473
# epoch 9399, loss with penalty 2.3208189010620117
# epoch 9400, loss with penalty 2.302544116973877
# epoch 9499, loss with penalty 2.3015451431274414
# epoch 9500, loss with penalty 2.3042893409729004
# epoch 9599, loss with penalty 2.302025318145752
# epoch 9600, loss with penalty 2.3005287647247314
# epoch 9699, loss with penalty 2.3040966987609863
# epoch 9700, loss with penalty 2.3007943630218506
# epoch 9799, loss with penalty 2.300015449523926
# epoch 9800, loss with penalty 2.299999952316284
# epoch 9899, loss with penalty 2.3173511028289795
# epoch 9900, loss with penalty 2.3137917518615723
# epoch 9999, loss with penalty 2.3475515842437744
# epoch 10000, loss with penalty 2.313380241394043
# epoch 10099, loss with penalty 2.304530620574951
# epoch 10100, loss with penalty 2.3035647869110107
# epoch 10199, loss with penalty 2.3126063346862793
# epoch 10200, loss with penalty 2.3186168670654297
# epoch 10299, loss with penalty 2.3120603561401367
# epoch 10300, loss with penalty 2.301704168319702
# epoch 10399, loss with penalty 2.329789400100708
# epoch 10400, loss with penalty 2.323237180709839
# epoch 10499, loss with penalty 2.3463239669799805
# epoch 10500, loss with penalty 2.346635103225708
# epoch 10599, loss with penalty 2.299994707107544
# epoch 10600, loss with penalty 2.3001012802124023
# epoch 10699, loss with penalty 2.334040403366089
# epoch 10700, loss with penalty 2.337759017944336
# epoch 10799, loss with penalty 2.3031678199768066
# epoch 10800, loss with penalty 2.304851770401001
# New min loss = tensor([2.2996], grad_fn=<AddBackward0>)
# epoch 10899, loss with penalty 2.308504819869995
# epoch 10900, loss with penalty 2.3076908588409424
# epoch 10999, loss with penalty 2.3078858852386475
# epoch 11000, loss with penalty 2.307236433029175
# epoch 11099, loss with penalty 2.309537649154663
# epoch 11100, loss with penalty 2.3148655891418457
# epoch 11199, loss with penalty 2.3600687980651855
# epoch 11200, loss with penalty 2.334315061569214
# epoch 11299, loss with penalty 2.3195934295654297
# epoch 11300, loss with penalty 2.3293280601501465
# epoch 11399, loss with penalty 2.299332618713379
# epoch 11400, loss with penalty 2.2997357845306396
# epoch 11499, loss with penalty 2.304931879043579
# epoch 11500, loss with penalty 2.3010172843933105
# epoch 11599, loss with penalty 2.328131675720215
# epoch 11600, loss with penalty 2.3274338245391846
# epoch 11699, loss with penalty 2.3181018829345703
# epoch 11700, loss with penalty 2.3033640384674072
# epoch 11799, loss with penalty 2.317927360534668
# epoch 11800, loss with penalty 2.3171608448028564
# epoch 11899, loss with penalty 2.3549633026123047
# epoch 11900, loss with penalty 2.3355584144592285
# epoch 11999, loss with penalty 2.322399616241455
# epoch 12000, loss with penalty 2.3185033798217773
# epoch 12099, loss with penalty 2.3365097045898438
# epoch 12100, loss with penalty 2.3299906253814697
# epoch 12199, loss with penalty 2.3181583881378174
# epoch 12200, loss with penalty 2.3235716819763184
# epoch 12299, loss with penalty 2.3000550270080566
# epoch 12300, loss with penalty 2.299520492553711
# epoch 12399, loss with penalty 2.314018726348877
# epoch 12400, loss with penalty 2.3069984912872314
# epoch 12499, loss with penalty 2.3093857765197754
# epoch 12500, loss with penalty 2.3036394119262695
# epoch 12599, loss with penalty 2.3002681732177734
# epoch 12600, loss with penalty 2.3029391765594482
# epoch 12699, loss with penalty 2.3372700214385986
# epoch 12700, loss with penalty 2.346067428588867
# epoch 12799, loss with penalty 3.9174888134002686
# epoch 12800, loss with penalty 19.45375633239746
# epoch 12899, loss with penalty 7.941583633422852
# epoch 12900, loss with penalty 7.911869049072266
# epoch 12999, loss with penalty 6.567234992980957
# epoch 13000, loss with penalty 6.556768894195557
# epoch 13099, loss with penalty 5.710150241851807
# epoch 13100, loss with penalty 5.703161239624023
# epoch 13199, loss with penalty 5.116344928741455
# epoch 13200, loss with penalty 5.111289978027344
# epoch 13299, loss with penalty 4.6713361740112305
# epoch 13300, loss with penalty 4.667416095733643
# epoch 13399, loss with penalty 4.318105697631836
# epoch 13400, loss with penalty 4.314925193786621
# epoch 13499, loss with penalty 4.0289225578308105
# epoch 13500, loss with penalty 4.026303768157959
# epoch 13599, loss with penalty 3.7890021800994873
# epoch 13600, loss with penalty 3.7868154048919678
# epoch 13699, loss with penalty 3.5886013507843018
# epoch 13700, loss with penalty 3.586772918701172
# epoch 13799, loss with penalty 3.420137643814087
# epoch 13800, loss with penalty 3.418595314025879
# epoch 13899, loss with penalty 3.2773821353912354
# epoch 13900, loss with penalty 3.2760696411132812
# epoch 13999, loss with penalty 3.1553409099578857
# epoch 14000, loss with penalty 3.1542086601257324
# epoch 14099, loss with penalty 3.0501251220703125
# epoch 14100, loss with penalty 3.0491509437561035
# epoch 14199, loss with penalty 2.958784580230713
# epoch 14200, loss with penalty 2.957932472229004
# epoch 14299, loss with penalty 2.879037618637085
# epoch 14300, loss with penalty 2.8782923221588135
# epoch 14399, loss with penalty 2.8091275691986084
# epoch 14400, loss with penalty 2.808471441268921
# epoch 14499, loss with penalty 2.7476484775543213
# epoch 14500, loss with penalty 2.7470743656158447
# epoch 14599, loss with penalty 2.6934654712677
# epoch 14600, loss with penalty 2.6929574012756348
# epoch 14699, loss with penalty 2.645636796951294
# epoch 14700, loss with penalty 2.645189046859741
# epoch 14799, loss with penalty 2.6033785343170166
# epoch 14800, loss with penalty 2.6029820442199707
# epoch 14899, loss with penalty 2.5660321712493896
# epoch 14900, loss with penalty 2.565681219100952
# epoch 14999, loss with penalty 2.5330333709716797
# Using potential function defined as class takes 5172.543023824692
# Before normalization:
# tensor([[-0.0008,  0.0052,  0.0051, -0.0480,  0.0893,  0.0807, -0.0654,  0.0462,
#          -0.0552,  0.1374, -0.0637,  0.0360, -0.0239, -0.0985, -0.0124,  0.0289,
#           0.0007, -0.0174,  0.1091, -0.0117,  0.0276,  0.1487, -0.0282,  0.0927,
#          -0.0103, -0.0006,  0.0317, -0.1377,  0.0826, -0.0041,  0.0690,  0.0116,
#           0.0270, -0.0450,  0.0679,  0.0164, -0.0558,  0.0159,  0.0443, -0.0136,
#          -0.0310,  0.0429,  0.0720, -0.0195, -0.0366, -0.0381,  0.1101, -0.1146,
#           0.0737,  0.0049, -0.0097, -0.0198, -0.1245,  0.0305,  0.0226, -0.0328,
#          -0.0295,  0.0905, -0.0153,  0.0205]])
# tensor([0.0324])
# After normalization:
# tensor([[-0.0008,  0.0052,  0.0051, -0.0480,  0.0893,  0.0808, -0.0655,  0.0462,
#          -0.0552,  0.1375, -0.0637,  0.0360, -0.0239, -0.0986, -0.0124,  0.0290,
#           0.0007, -0.0174,  0.1092, -0.0117,  0.0276,  0.1488, -0.0282,  0.0928,
#          -0.0103, -0.0006,  0.0317, -0.1378,  0.0827, -0.0041,  0.0691,  0.0116,
#           0.0270, -0.0451,  0.0680,  0.0164, -0.0558,  0.0159,  0.0443, -0.0136,
#          -0.0310,  0.0429,  0.0720, -0.0195, -0.0366, -0.0381,  0.1102, -0.1146,
#           0.0737,  0.0049, -0.0097, -0.0199, -0.1246,  0.0305,  0.0226, -0.0328,
#          -0.0295,  0.0906, -0.0153,  0.0206]])
# tensor([0.0324])
# c value = tensor([1.0006], grad_fn=<MulBackward0>)
# Before normalization:
# tensor([[ 2.0766e-04, -9.0987e-04,  6.6514e-02, -3.5113e-03,  3.8579e-04,
#           7.9321e-04,  7.9497e-04, -2.8184e-03,  5.3697e-03,  1.7073e-04,
#           2.2356e-05,  2.6078e-03,  1.1880e-03, -4.1908e-04,  6.2926e-04,
#          -7.2992e-05, -2.6102e-03,  2.8518e-05,  1.2061e-03, -5.1243e-04,
#          -5.1812e-04, -1.5991e-04,  3.2346e-04, -1.2028e-04,  7.0608e-02,
#           4.1702e-04,  3.9750e-02,  6.0955e-02,  1.0119e-04, -6.8894e-04,
#          -7.1172e-04, -7.1672e-04,  3.2935e-04, -4.2962e-04,  1.1775e-03,
#           3.6254e-04, -1.1605e-03,  2.0666e-04, -3.9172e-04, -4.6977e-04,
#          -1.7198e-04, -1.1697e-03, -6.0462e-05,  1.4384e-03,  1.1229e-03,
#          -2.4180e-05, -9.1316e-05,  3.0754e-02, -3.0513e-02,  4.2736e-04,
#          -1.0563e-04, -7.7825e-04, -9.6316e-02,  1.2753e-03, -5.9171e-04,
#           5.2637e-03,  1.3103e-03, -1.6875e-03,  6.2459e-02, -7.0819e-04]])
# tensor([-0.1893])
# After normalization:
# tensor([[ 2.0776e-04, -9.1032e-04,  6.6547e-02, -3.5130e-03,  3.8598e-04,
#           7.9359e-04,  7.9535e-04, -2.8198e-03,  5.3723e-03,  1.7081e-04,
#           2.2366e-05,  2.6091e-03,  1.1886e-03, -4.1929e-04,  6.2956e-04,
#          -7.3027e-05, -2.6115e-03,  2.8532e-05,  1.2067e-03, -5.1268e-04,
#          -5.1837e-04, -1.5999e-04,  3.2361e-04, -1.2034e-04,  7.0643e-02,
#           4.1722e-04,  3.9769e-02,  6.0985e-02,  1.0124e-04, -6.8928e-04,
#          -7.1207e-04, -7.1707e-04,  3.2951e-04, -4.2983e-04,  1.1781e-03,
#           3.6272e-04, -1.1610e-03,  2.0676e-04, -3.9191e-04, -4.7000e-04,
#          -1.7206e-04, -1.1702e-03, -6.0492e-05,  1.4391e-03,  1.1235e-03,
#          -2.4191e-05, -9.1360e-05,  3.0769e-02, -3.0528e-02,  4.2757e-04,
#          -1.0568e-04, -7.7862e-04, -9.6363e-02,  1.2759e-03, -5.9200e-04,
#           5.2662e-03,  1.3109e-03, -1.6883e-03,  6.2490e-02, -7.0853e-04]])
# tensor([-0.1894])
# c value = tensor([1.0005], grad_fn=<MulBackward0>)

# %%
del model_21_sin
del adam_opt_21_sin

model_21_sin = Nonlinear_2(layer_width=60, use_sin=True)
adam_opt_21_sin = torch.optim.Adam(model_21_sin.parameters(), 
                                    lr=learningRate, 
                                    betas=(0.9, 0.999), 
                                    eps=1e-08, 
                                    weight_decay=0, 
                                    amsgrad=False)

res2_21_sin = auto_test_documentation(model_21_sin, adam_opt_21_sin, p_fn2, 
                                      model_name='model_21_sin_pfn2',
                                      res_path=RESULT_PATH,
                                      loss_fname='loss_21_sin_pfn2',
                                      loss_with_pen_fname = 'loss_pen_21_sin_pfn2')
# Out:
# Start time is 2022-08-10 00:51:29.870354-04:00
# Initiate first min loss = tensor([49.4194], grad_fn=<AddBackward0>)
# epoch 0, loss with penalty 49.41940689086914
# New min loss = tensor([11.6508], grad_fn=<AddBackward0>)
# New min loss = tensor([4.9778], grad_fn=<AddBackward0>)
# New min loss = tensor([3.9109], grad_fn=<AddBackward0>)
# New min loss = tensor([3.8013], grad_fn=<AddBackward0>)
# New min loss = tensor([3.6229], grad_fn=<AddBackward0>)
# New min loss = tensor([3.5349], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4477], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4072], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3618], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3296], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2945], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2795], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2668], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2148], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1666], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1593], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1280], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1008], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0931], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0843], grad_fn=<AddBackward0>)
# epoch 99, loss with penalty 3.0843253135681152
# New min loss = tensor([3.0535], grad_fn=<AddBackward0>)
# epoch 100, loss with penalty 3.053537130355835
# New min loss = tensor([3.0293], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0130], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0032], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9809], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9740], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9706], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9533], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9379], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9331], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9230], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9064], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8969], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8900], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8763], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8630], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8551], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8447], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8311], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8210], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8121], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7998], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7879], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7785], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7677], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7556], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7455], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7355], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7239], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7128], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7028], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6919], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6807], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6705], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6601], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6489], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6383], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6281], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6173], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6066], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5964], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5859], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5752], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5650], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5547], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5442], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5339], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5238], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5135], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5032], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4932], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4830], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4729], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4630], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4531], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4431], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4332], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4234], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4136], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4039], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3943], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3847], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3751], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3656], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3562], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3468], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3375], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3283], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3191], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3099], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3009], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2919], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2829], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2741], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2652], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2565], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2478], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2392], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2306], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2222], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2137], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2054], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1971], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1889], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1808], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1727], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1647], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1568], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1489], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1411], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1334], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1258], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1182], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1107], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1033], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0959], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0886], grad_fn=<AddBackward0>)
# epoch 199, loss with penalty 2.088613986968994
# New min loss = tensor([2.0814], grad_fn=<AddBackward0>)
# epoch 200, loss with penalty 2.081393003463745
# New min loss = tensor([2.0742], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0672], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0601], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0532], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0463], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0395], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0328], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0261], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0195], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0130], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0066], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0002], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9938], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9876], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9814], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9753], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9692], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9632], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9573], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9514], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9456], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9399], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9342], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9286], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9231], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9176], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9121], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9068], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9015], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8962], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8910], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8859], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8808], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8758], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8708], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8659], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8611], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8563], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8516], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8469], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8422], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8377], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8331], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8286], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8242], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8198], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8155], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8112], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8070], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8028], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7987], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7946], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7905], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7865], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7826], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7787], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7748], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7710], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7672], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7634], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7597], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7561], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7525], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7489], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7453], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7418], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7384], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7349], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7316], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7282], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7249], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7216], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7184], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7152], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7120], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7088], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7057], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7027], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6996], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6966], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6936], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6907], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6878], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6849], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6820], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6792], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6764], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6736], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6709], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6681], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6655], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6628], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6602], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6575], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6550], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6524], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6499], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6474], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6449], grad_fn=<AddBackward0>)
# epoch 299, loss with penalty 1.6448837518692017
# New min loss = tensor([1.6424], grad_fn=<AddBackward0>)
# epoch 300, loss with penalty 1.6424249410629272
# New min loss = tensor([1.6400], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6376], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6352], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6328], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6305], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6282], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6259], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6236], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6213], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6191], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6169], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6147], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6125], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6103], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6082], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6061], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6040], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6019], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5999], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5978], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5958], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5938], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5918], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5898], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5879], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5860], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5840], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5821], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5802], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5784], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5765], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5747], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5729], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5710], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5693], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5675], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5657], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5640], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5622], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5605], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5588], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5571], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5554], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5538], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5521], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5505], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5489], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5472], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5456], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5441], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5425], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5409], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5394], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5378], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5363], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5348], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5333], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5318], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5303], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5289], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5274], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5260], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5245], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5231], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5217], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5203], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5189], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5175], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5161], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5148], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5134], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5121], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5108], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5094], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5081], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5068], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5055], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5043], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5030], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5017], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5005], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4992], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4980], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4968], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4955], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4943], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4931], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4920], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4908], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4896], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4884], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4873], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4861], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4850], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4839], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4827], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4816], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4805], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4794], grad_fn=<AddBackward0>)
# epoch 399, loss with penalty 1.4794169664382935
# New min loss = tensor([1.4783], grad_fn=<AddBackward0>)
# epoch 400, loss with penalty 1.4783238172531128
# New min loss = tensor([1.4772], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4762], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4751], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4740], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4730], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4719], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4709], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4699], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4689], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4678], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4668], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4649], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4629], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4610], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4591], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4572], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4553], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4535], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4517], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4499], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4482], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4465], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4448], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4431], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4415], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4399], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4383], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4367], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4352], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4337], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4322], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4307], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4293], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4279], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4265], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4251], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4237], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4224], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4211], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4198], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4185], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4173], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4160], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4148], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4137], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4125], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4113], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4102], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4091], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4080], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4069], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4059], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4049], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4038], grad_fn=<AddBackward0>)
# epoch 499, loss with penalty 1.4028469324111938
# New min loss = tensor([1.4024], grad_fn=<AddBackward0>)
# epoch 500, loss with penalty 1.4023544788360596
# New min loss = tensor([1.4009], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3995], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3981], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3968], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3955], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3942], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3930], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3918], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3906], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3895], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3884], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3873], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3863], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3853], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3840], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3827], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3815], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3804], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3793], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3782], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3772], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3759], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3748], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3736], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3726], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3716], grad_fn=<AddBackward0>)
# epoch 599, loss with penalty 1.3708089590072632
# epoch 600, loss with penalty 1.370621919631958
# New min loss = tensor([1.3704], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3694], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3683], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3672], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3662], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3651], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3641], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3630], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3619], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3608], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3598], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3588], grad_fn=<AddBackward0>)
# epoch 699, loss with penalty 1.3586840629577637
# epoch 700, loss with penalty 1.3586094379425049
# New min loss = tensor([1.3577], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3566], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3556], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3546], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3536], grad_fn=<AddBackward0>)
# epoch 799, loss with penalty 1.3534754514694214
# epoch 800, loss with penalty 1.3534386157989502
# New min loss = tensor([1.3526], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3515], grad_fn=<AddBackward0>)
# epoch 899, loss with penalty 1.3506510257720947
# epoch 900, loss with penalty 1.3506296873092651
# New min loss = tensor([1.3505], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3495], grad_fn=<AddBackward0>)
# epoch 999, loss with penalty 1.3488154411315918
# epoch 1000, loss with penalty 1.348799467086792
# New min loss = tensor([1.3485], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3475], grad_fn=<AddBackward0>)
# epoch 1099, loss with penalty 1.347455620765686
# epoch 1100, loss with penalty 1.3474416732788086
# New min loss = tensor([1.3465], grad_fn=<AddBackward0>)
# epoch 1199, loss with penalty 1.346337914466858
# epoch 1200, loss with penalty 1.3463268280029297
# New min loss = tensor([1.3455], grad_fn=<AddBackward0>)
# epoch 1299, loss with penalty 1.3453609943389893
# epoch 1300, loss with penalty 1.3453518152236938
# New min loss = tensor([1.3445], grad_fn=<AddBackward0>)
# epoch 1399, loss with penalty 1.3444697856903076
# epoch 1400, loss with penalty 1.3444623947143555
# epoch 1499, loss with penalty 1.3436415195465088
# epoch 1500, loss with penalty 1.3436318635940552
# New min loss = tensor([1.3435], grad_fn=<AddBackward0>)
# epoch 1599, loss with penalty 1.342861533164978
# epoch 1600, loss with penalty 1.3428544998168945
# New min loss = tensor([1.3425], grad_fn=<AddBackward0>)
# epoch 1699, loss with penalty 1.34213125705719
# epoch 1700, loss with penalty 1.3421260118484497
# New min loss = tensor([1.3415], grad_fn=<AddBackward0>)
# epoch 1799, loss with penalty 1.3414477109909058
# epoch 1800, loss with penalty 1.341439127922058
# epoch 1899, loss with penalty 1.3521838188171387
# epoch 1900, loss with penalty 1.3569679260253906
# New min loss = tensor([1.3405], grad_fn=<AddBackward0>)
# epoch 1999, loss with penalty 1.3402985334396362
# epoch 2000, loss with penalty 1.3403022289276123
# epoch 2099, loss with penalty 1.3424432277679443
# epoch 2100, loss with penalty 1.341087818145752
# New min loss = tensor([1.3395], grad_fn=<AddBackward0>)
# epoch 2199, loss with penalty 1.638593077659607
# epoch 2200, loss with penalty 1.831620693206787
# epoch 2299, loss with penalty 1.339501976966858
# epoch 2300, loss with penalty 1.339446783065796
# epoch 2399, loss with penalty 1.3918688297271729
# epoch 2400, loss with penalty 1.3629668951034546
# New min loss = tensor([1.3384], grad_fn=<AddBackward0>)
# epoch 2499, loss with penalty 1.3381195068359375
# epoch 2500, loss with penalty 1.3381353616714478
# epoch 2599, loss with penalty 1.338396430015564
# epoch 2600, loss with penalty 1.3386410474777222
# New min loss = tensor([1.3374], grad_fn=<AddBackward0>)
# epoch 2699, loss with penalty 3.3044261932373047
# epoch 2700, loss with penalty 3.0955235958099365
# epoch 2799, loss with penalty 1.3372299671173096
# epoch 2800, loss with penalty 1.3371753692626953
# epoch 2899, loss with penalty 2.7855281829833984
# epoch 2900, loss with penalty 3.2646331787109375
# epoch 2999, loss with penalty 1.336493730545044
# epoch 3000, loss with penalty 1.3364983797073364
# New min loss = tensor([1.3364], grad_fn=<AddBackward0>)
# epoch 3099, loss with penalty 1.5978325605392456
# epoch 3100, loss with penalty 1.7203209400177002
# epoch 3199, loss with penalty 1.335932970046997
# epoch 3200, loss with penalty 1.3359184265136719
# epoch 3299, loss with penalty 1.3422220945358276
# epoch 3300, loss with penalty 1.3587323427200317
# epoch 3399, loss with penalty 1.3533508777618408
# epoch 3400, loss with penalty 1.361382246017456
# New min loss = tensor([1.3354], grad_fn=<AddBackward0>)
# epoch 3499, loss with penalty 1.3354125022888184
# epoch 3500, loss with penalty 1.3353973627090454
# epoch 3599, loss with penalty 1.3402037620544434
# epoch 3600, loss with penalty 1.3685418367385864
# epoch 3699, loss with penalty 1.334992527961731
# epoch 3700, loss with penalty 1.3349993228912354
# epoch 3799, loss with penalty 1.335294485092163
# epoch 3800, loss with penalty 1.3359463214874268
# epoch 3899, loss with penalty 2.791586399078369
# epoch 3900, loss with penalty 2.276297092437744
# epoch 3999, loss with penalty 1.3346518278121948
# epoch 4000, loss with penalty 1.3346503973007202
# epoch 4099, loss with penalty 1.5722492933273315
# epoch 4100, loss with penalty 1.5357005596160889
# New min loss = tensor([1.3344], grad_fn=<AddBackward0>)
# epoch 4199, loss with penalty 1.3343154191970825
# epoch 4200, loss with penalty 1.3343144655227661
# epoch 4299, loss with penalty 1.346767544746399
# epoch 4300, loss with penalty 1.3461451530456543
# epoch 4399, loss with penalty 1.3544844388961792
# epoch 4400, loss with penalty 1.6149927377700806
# epoch 4499, loss with penalty 1.3343782424926758
# epoch 4500, loss with penalty 1.3343857526779175
# epoch 4599, loss with penalty 1.3364814519882202
# epoch 4600, loss with penalty 1.3351587057113647
# epoch 4699, loss with penalty 1.4305922985076904
# epoch 4700, loss with penalty 1.3800212144851685
# epoch 4799, loss with penalty 1.3367688655853271
# epoch 4800, loss with penalty 1.3379957675933838
# epoch 4899, loss with penalty 1.333846926689148
# epoch 4900, loss with penalty 1.3337223529815674
# epoch 4999, loss with penalty 1.4892022609710693
# epoch 5000, loss with penalty 1.4536118507385254
# epoch 5099, loss with penalty 1.3334723711013794
# epoch 5100, loss with penalty 1.3334712982177734
# epoch 5199, loss with penalty 1.3413418531417847
# epoch 5200, loss with penalty 1.3486945629119873
# New min loss = tensor([1.3334], grad_fn=<AddBackward0>)
# epoch 5299, loss with penalty 1.33333420753479
# epoch 5300, loss with penalty 1.3333319425582886
# epoch 5399, loss with penalty 1.3846663236618042
# epoch 5400, loss with penalty 1.3624563217163086
# epoch 5499, loss with penalty 1.3332009315490723
# epoch 5500, loss with penalty 1.3331977128982544
# epoch 5599, loss with penalty 1.3347666263580322
# epoch 5600, loss with penalty 1.345792293548584
# epoch 5699, loss with penalty 1.3330557346343994
# epoch 5700, loss with penalty 1.3330570459365845
# epoch 5799, loss with penalty 1.3366457223892212
# epoch 5800, loss with penalty 1.3370908498764038
# epoch 5899, loss with penalty 3.0744402408599854
# epoch 5900, loss with penalty 2.2779107093811035
# epoch 5999, loss with penalty 1.334648609161377
# epoch 6000, loss with penalty 1.334943175315857
# epoch 6099, loss with penalty 1.3349041938781738
# epoch 6100, loss with penalty 1.3353791236877441
# epoch 6199, loss with penalty 1.3329613208770752
# epoch 6200, loss with penalty 1.3330295085906982
# epoch 6299, loss with penalty 1.3334776163101196
# epoch 6300, loss with penalty 1.333810567855835
# epoch 6399, loss with penalty 1.3593990802764893
# epoch 6400, loss with penalty 1.3580760955810547
# epoch 6499, loss with penalty 1.420663595199585
# epoch 6500, loss with penalty 1.4553205966949463
# epoch 6599, loss with penalty 1.332825779914856
# epoch 6600, loss with penalty 1.3329858779907227
# epoch 6699, loss with penalty 1.3336503505706787
# epoch 6700, loss with penalty 1.3331044912338257
# epoch 6799, loss with penalty 1.3326185941696167
# epoch 6800, loss with penalty 1.332617998123169
# epoch 6899, loss with penalty 1.3636012077331543
# epoch 6900, loss with penalty 1.3826794624328613
# epoch 6999, loss with penalty 1.3327250480651855
# epoch 7000, loss with penalty 1.3326786756515503
# epoch 7099, loss with penalty 1.337899088859558
# epoch 7100, loss with penalty 1.3408783674240112
# epoch 7199, loss with penalty 1.332883596420288
# epoch 7200, loss with penalty 1.3329739570617676
# epoch 7299, loss with penalty 1.3479537963867188
# epoch 7300, loss with penalty 1.3569164276123047
# epoch 7399, loss with penalty 1.332944393157959
# epoch 7400, loss with penalty 1.3329765796661377
# epoch 7499, loss with penalty 1.4270864725112915
# epoch 7500, loss with penalty 1.4892079830169678
# epoch 7599, loss with penalty 1.3328379392623901
# epoch 7600, loss with penalty 1.3328901529312134
# epoch 7699, loss with penalty 1.3328183889389038
# epoch 7700, loss with penalty 1.3329594135284424
# epoch 7799, loss with penalty 1.3332622051239014
# epoch 7800, loss with penalty 1.3336645364761353
# epoch 7899, loss with penalty 1.3325591087341309
# epoch 7900, loss with penalty 1.3325573205947876
# epoch 7999, loss with penalty 1.3400639295578003
# epoch 8000, loss with penalty 1.3334077596664429
# epoch 8099, loss with penalty 1.3326313495635986
# epoch 8100, loss with penalty 1.332627773284912
# epoch 8199, loss with penalty 1.3410557508468628
# epoch 8200, loss with penalty 1.4138176441192627
# epoch 8299, loss with penalty 1.3326398134231567
# epoch 8300, loss with penalty 1.3326317071914673
# epoch 8399, loss with penalty 1.3603638410568237
# epoch 8400, loss with penalty 1.3338764905929565
# epoch 8499, loss with penalty 1.3325612545013428
# epoch 8500, loss with penalty 1.3325603008270264
# epoch 8599, loss with penalty 1.5489411354064941
# epoch 8600, loss with penalty 1.5337467193603516
# epoch 8699, loss with penalty 1.332701325416565
# epoch 8700, loss with penalty 1.3326926231384277
# New min loss = tensor([1.3324], grad_fn=<AddBackward0>)
# epoch 8799, loss with penalty 1.3323808908462524
# epoch 8800, loss with penalty 1.3323795795440674
# epoch 8899, loss with penalty 1.3427718877792358
# epoch 8900, loss with penalty 1.334015965461731
# epoch 8999, loss with penalty 1.3328783512115479
# epoch 9000, loss with penalty 1.3330819606781006
# epoch 9099, loss with penalty 1.3328967094421387
# epoch 9100, loss with penalty 1.3328441381454468
# epoch 9199, loss with penalty 1.3337026834487915
# epoch 9200, loss with penalty 1.3339368104934692
# epoch 9299, loss with penalty 1.3429046869277954
# epoch 9300, loss with penalty 1.3454864025115967
# epoch 9399, loss with penalty 1.358681559562683
# epoch 9400, loss with penalty 1.3722971677780151
# epoch 9499, loss with penalty 1.3404371738433838
# epoch 9500, loss with penalty 1.3434511423110962
# epoch 9599, loss with penalty 1.3330411911010742
# epoch 9600, loss with penalty 1.332726001739502
# epoch 9699, loss with penalty 1.4587063789367676
# epoch 9700, loss with penalty 1.484145998954773
# epoch 9799, loss with penalty 1.3853338956832886
# epoch 9800, loss with penalty 1.3959150314331055
# epoch 9899, loss with penalty 1.472729206085205
# epoch 9900, loss with penalty 1.378607153892517
# epoch 9999, loss with penalty 1.353760838508606
# epoch 10000, loss with penalty 1.361304759979248
# epoch 10099, loss with penalty 1.350279450416565
# epoch 10100, loss with penalty 1.3401036262512207
# epoch 10199, loss with penalty 1.4860321283340454
# epoch 10200, loss with penalty 1.4059237241744995
# epoch 10299, loss with penalty 1.3783925771713257
# epoch 10300, loss with penalty 1.3933393955230713
# epoch 10399, loss with penalty 1.3331356048583984
# epoch 10400, loss with penalty 1.3336260318756104
# epoch 10499, loss with penalty 1.3351432085037231
# epoch 10500, loss with penalty 1.335397481918335
# epoch 10599, loss with penalty 1.3520320653915405
# epoch 10600, loss with penalty 1.3561923503875732
# epoch 10699, loss with penalty 1.380812168121338
# epoch 10700, loss with penalty 1.379895806312561
# epoch 10799, loss with penalty 13.358735084533691
# epoch 10800, loss with penalty 12.300041198730469
# epoch 10899, loss with penalty 7.841140270233154
# epoch 10900, loss with penalty 7.822350978851318
# epoch 10999, loss with penalty 6.129178524017334
# epoch 11000, loss with penalty 6.11394739151001
# epoch 11099, loss with penalty 4.803092956542969
# epoch 11100, loss with penalty 4.7918314933776855
# epoch 11199, loss with penalty 3.8573944568634033
# epoch 11200, loss with penalty 3.8496510982513428
# epoch 11299, loss with penalty 3.22094464302063
# epoch 11300, loss with penalty 3.2158291339874268
# epoch 11399, loss with penalty 2.803402900695801
# epoch 11400, loss with penalty 2.8000576496124268
# epoch 11499, loss with penalty 2.5290639400482178
# epoch 11500, loss with penalty 2.526848077774048
# epoch 11599, loss with penalty 2.3446452617645264
# epoch 11600, loss with penalty 2.343125581741333
# epoch 11699, loss with penalty 2.2154321670532227
# epoch 11700, loss with penalty 2.2143383026123047
# epoch 11799, loss with penalty 2.1196036338806152
# epoch 11800, loss with penalty 2.1187632083892822
# epoch 11899, loss with penalty 2.0436758995056152
# epoch 11900, loss with penalty 2.0429859161376953
# epoch 11999, loss with penalty 1.979431390762329
# epoch 12000, loss with penalty 1.9788310527801514
# epoch 12099, loss with penalty 1.9219579696655273
# epoch 12100, loss with penalty 1.9214074611663818
# epoch 12199, loss with penalty 1.8684026002883911
# epoch 12200, loss with penalty 1.8678803443908691
# epoch 12299, loss with penalty 1.8172194957733154
# epoch 12300, loss with penalty 1.816716194152832
# epoch 12399, loss with penalty 1.767703652381897
# epoch 12400, loss with penalty 1.7672165632247925
# epoch 12499, loss with penalty 1.7197004556655884
# epoch 12500, loss with penalty 1.7192283868789673
# epoch 12599, loss with penalty 1.6734182834625244
# epoch 12600, loss with penalty 1.672965407371521
# epoch 12699, loss with penalty 1.629275918006897
# epoch 12700, loss with penalty 1.6288466453552246
# epoch 12799, loss with penalty 1.587814450263977
# epoch 12800, loss with penalty 1.587415099143982
# epoch 12899, loss with penalty 1.5495694875717163
# epoch 12900, loss with penalty 1.5492045879364014
# epoch 12999, loss with penalty 1.5149970054626465
# epoch 13000, loss with penalty 1.5146708488464355
# epoch 13099, loss with penalty 1.4844156503677368
# epoch 13100, loss with penalty 1.4841294288635254
# epoch 13199, loss with penalty 1.4579519033432007
# epoch 13200, loss with penalty 1.4577069282531738
# epoch 13299, loss with penalty 1.435544729232788
# epoch 13300, loss with penalty 1.4353405237197876
# epoch 13399, loss with penalty 1.4169615507125854
# epoch 13400, loss with penalty 1.4167957305908203
# epoch 13499, loss with penalty 1.401845932006836
# epoch 13500, loss with penalty 1.401711344718933
# epoch 13599, loss with penalty 1.3897547721862793
# epoch 13600, loss with penalty 1.3896472454071045
# epoch 13699, loss with penalty 1.3802127838134766
# epoch 13700, loss with penalty 1.3801300525665283
# epoch 13799, loss with penalty 1.3727593421936035
# epoch 13800, loss with penalty 1.3726946115493774
# epoch 13899, loss with penalty 1.36696457862854
# epoch 13900, loss with penalty 1.3669146299362183
# epoch 13999, loss with penalty 1.3624531030654907
# epoch 14000, loss with penalty 1.3624132871627808
# epoch 14099, loss with penalty 1.3589073419570923
# epoch 14100, loss with penalty 1.3588767051696777
# epoch 14199, loss with penalty 1.3560776710510254
# epoch 14200, loss with penalty 1.356052279472351
# epoch 14299, loss with penalty 1.3537651300430298
# epoch 14300, loss with penalty 1.353743553161621
# epoch 14399, loss with penalty 1.3518232107162476
# epoch 14400, loss with penalty 1.351806402206421
# epoch 14499, loss with penalty 1.3501434326171875
# epoch 14500, loss with penalty 1.3501278162002563
# epoch 14599, loss with penalty 1.3486549854278564
# epoch 14600, loss with penalty 1.3486418724060059
# epoch 14699, loss with penalty 1.3473073244094849
# epoch 14700, loss with penalty 1.3472954034805298
# epoch 14799, loss with penalty 1.3460692167282104
# epoch 14800, loss with penalty 1.3460575342178345
# epoch 14899, loss with penalty 1.3449159860610962
# epoch 14900, loss with penalty 1.3449057340621948
# epoch 14999, loss with penalty 1.343837857246399
# Using potential function defined as class takes 4769.753473043442
# Before normalization:
# tensor([[-0.0037, -0.0258, -0.0008, -0.0311,  0.0111,  0.0145, -0.0649, -0.0444,
#          -0.0364,  0.0333, -0.0119,  0.1299, -0.0043, -0.0829, -0.0400,  0.0906,
#          -0.0423, -0.0184, -0.0119,  0.0035,  0.0390,  0.0371,  0.0211,  0.0301,
#           0.0419,  0.0363,  0.0203,  0.0433, -0.0409,  0.0321,  0.0949, -0.0127,
#           0.0118,  0.0080,  0.0287, -0.0258, -0.0286,  0.0644, -0.0203, -0.0157,
#           0.0246,  0.0735, -0.0536, -0.0252, -0.1261, -0.0300,  0.0103, -0.0063,
#           0.0246, -0.0232,  0.1025, -0.1521,  0.1113,  0.0310,  0.1413, -0.0057,
#          -0.0348,  0.0061,  0.0185, -0.0417]])
# tensor([0.0047])
# After normalization:
# tensor([[-0.0037, -0.0258, -0.0008, -0.0311,  0.0111,  0.0145, -0.0650, -0.0444,
#          -0.0364,  0.0334, -0.0119,  0.1299, -0.0043, -0.0830, -0.0400,  0.0906,
#          -0.0424, -0.0184, -0.0119,  0.0035,  0.0390,  0.0371,  0.0211,  0.0301,
#           0.0419,  0.0363,  0.0203,  0.0434, -0.0409,  0.0321,  0.0949, -0.0127,
#           0.0118,  0.0080,  0.0288, -0.0258, -0.0286,  0.0645, -0.0203, -0.0157,
#           0.0246,  0.0735, -0.0536, -0.0252, -0.1262, -0.0300,  0.0103, -0.0063,
#           0.0246, -0.0233,  0.1026, -0.1522,  0.1114,  0.0310,  0.1414, -0.0057,
#          -0.0348,  0.0061,  0.0185, -0.0417]])
# tensor([0.0047])
# c value = tensor([1.0003], grad_fn=<MulBackward0>)
# Before normalization:
# tensor([[ 6.1684e-04, -7.6540e-06,  1.1036e-03, -6.4340e-04, -9.5754e-04,
#          -5.5560e-04, -2.9502e-02, -2.0689e-03, -1.2148e-04,  5.6955e-04,
#           7.3713e-05, -2.7857e-02, -7.6075e-04,  1.1133e-03,  3.2821e-03,
#          -5.4599e-02, -4.1568e-03,  1.6961e-04,  9.5866e-04, -3.8013e-02,
#           8.4714e-04, -2.8288e-04,  2.1669e-03,  7.8513e-04, -5.6093e-04,
#          -1.3874e-04, -8.7725e-04, -4.0949e-04,  5.7824e-02,  6.7424e-03,
#           1.3421e-02,  1.8975e-05, -2.7546e-04, -1.1593e-01, -7.9419e-04,
#           2.8950e-05, -1.0740e-03, -1.0484e-01, -1.5539e-03,  2.2481e-03,
#          -1.3461e-03, -1.8772e-04,  1.2141e-02,  8.2244e-04,  5.6178e-02,
#           3.7940e-04, -5.5874e-05,  5.7596e-04,  6.6079e-05, -1.2000e-03,
#          -1.1749e-03,  2.3416e-03,  4.1676e-02, -2.6404e-02, -2.5641e-02,
#          -1.6233e-04, -8.5989e-04, -1.2739e-03,  7.3150e-04, -6.9909e-04]])
# tensor([-0.0817])
# After normalization:
# tensor([[ 6.1704e-04, -7.6565e-06,  1.1039e-03, -6.4361e-04, -9.5786e-04,
#          -5.5579e-04, -2.9512e-02, -2.0696e-03, -1.2152e-04,  5.6974e-04,
#           7.3738e-05, -2.7866e-02, -7.6100e-04,  1.1136e-03,  3.2832e-03,
#          -5.4617e-02, -4.1582e-03,  1.6967e-04,  9.5898e-04, -3.8025e-02,
#           8.4742e-04, -2.8298e-04,  2.1677e-03,  7.8539e-04, -5.6112e-04,
#          -1.3878e-04, -8.7754e-04, -4.0963e-04,  5.7844e-02,  6.7446e-03,
#           1.3425e-02,  1.8982e-05, -2.7555e-04, -1.1596e-01, -7.9445e-04,
#           2.8959e-05, -1.0744e-03, -1.0488e-01, -1.5544e-03,  2.2489e-03,
#          -1.3466e-03, -1.8778e-04,  1.2145e-02,  8.2272e-04,  5.6197e-02,
#           3.7952e-04, -5.5893e-05,  5.7615e-04,  6.6101e-05, -1.2004e-03,
#          -1.1753e-03,  2.3424e-03,  4.1689e-02, -2.6412e-02, -2.5649e-02,
#          -1.6238e-04, -8.6017e-04, -1.2743e-03,  7.3174e-04, -6.9932e-04]])
# tensor([-0.0818])
# c value = tensor([1.0003], grad_fn=<MulBackward0>)

# %%
del model_21_sin
del adam_opt_21_sin

model_21_sin = Nonlinear_2(layer_width=60, use_sin=True)
adam_opt_21_sin = torch.optim.Adam(model_21_sin.parameters(), 
                                    lr=learningRate, 
                                    betas=(0.9, 0.999), 
                                    eps=1e-08, 
                                    weight_decay=0, 
                                    amsgrad=False)

res2_21_sin = auto_test_documentation(model_21_sin, adam_opt_21_sin, p_fn3, 
                                      model_name='model_21_sin_pfn3',
                                      res_path=RESULT_PATH,
                                      loss_fname='loss_21_sin_pfn3',
                                      loss_with_pen_fname = 'loss_pen_21_sin_pfn3')
# Out:
# Start time is 2022-08-10 02:10:59.784001-04:00
# Initiate first min loss = tensor([894.9681], grad_fn=<AddBackward0>)
# epoch 0, loss with penalty 894.9680786132812
# New min loss = tensor([680.8812], grad_fn=<AddBackward0>)
# New min loss = tensor([193.7177], grad_fn=<AddBackward0>)
# New min loss = tensor([56.3192], grad_fn=<AddBackward0>)
# New min loss = tensor([10.5874], grad_fn=<AddBackward0>)
# New min loss = tensor([4.8206], grad_fn=<AddBackward0>)
# New min loss = tensor([3.9745], grad_fn=<AddBackward0>)
# New min loss = tensor([3.6103], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2534], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2215], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1871], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1649], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1522], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1427], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1353], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1280], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1215], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1150], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1093], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1054], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1034], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0944], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0856], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0783], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0758], grad_fn=<AddBackward0>)
# epoch 99, loss with penalty 3.0758047103881836
# New min loss = tensor([3.0720], grad_fn=<AddBackward0>)
# epoch 100, loss with penalty 3.072033166885376
# New min loss = tensor([3.0665], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0645], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0587], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0554], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0519], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0470], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0454], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0435], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0397], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0387], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0355], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0330], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0314], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0281], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0265], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0240], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0214], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0197], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0168], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0149], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0126], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0101], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0083], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0057], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0037], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0015], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9992], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9973], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9949], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9929], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9908], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9886], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9866], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9844], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9825], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9804], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9783], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9764], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9743], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9723], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9703], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9684], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9664], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9644], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9625], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9606], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9587], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9568], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9549], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9531], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9512], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9494], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9476], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9458], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9440], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9422], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9404], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9387], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9369], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9352], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9335], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9318], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9301], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9285], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9268], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9252], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9235], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9219], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9203], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9187], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9172], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9156], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9140], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9125], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9110], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9095], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9080], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9065], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9051], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9036], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9022], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9007], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8993], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8979], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8965], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8952], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8938], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8925], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8911], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8898], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8885], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8872], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8859], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8846], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8834], grad_fn=<AddBackward0>)
# epoch 199, loss with penalty 2.8833718299865723
# New min loss = tensor([2.8821], grad_fn=<AddBackward0>)
# epoch 200, loss with penalty 2.8821284770965576
# New min loss = tensor([2.8809], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8797], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8785], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8773], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8761], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8749], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8737], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8726], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8714], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8703], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8692], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8681], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8670], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8659], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8649], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8638], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8627], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8617], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8607], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8597], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8587], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8567], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8548], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8529], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8510], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8492], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8474], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8457], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8440], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8423], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8407], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8391], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8375], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8360], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8345], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8331], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8317], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8303], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8289], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8276], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8263], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8250], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8238], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8225], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8214], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8202], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8191], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8179], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8169], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8158], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8148], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8137], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8123], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8108], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8094], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8081], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8068], grad_fn=<AddBackward0>)
# epoch 299, loss with penalty 2.8063480854034424
# epoch 300, loss with penalty 2.805926561355591
# New min loss = tensor([2.8055], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8043], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8031], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8020], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8008], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7998], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7987], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7977], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7964], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7951], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7939], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7927], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7916], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7905], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7895], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7885], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7872], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7861], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7850], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7839], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7828], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7818], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7807], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7795], grad_fn=<AddBackward0>)
# epoch 399, loss with penalty 2.779005289077759
# epoch 400, loss with penalty 2.7788238525390625
# New min loss = tensor([2.7785], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7774], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7763], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7752], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7741], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7730], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7720], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7709], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7698], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7688], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7678], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7667], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7656], grad_fn=<AddBackward0>)
# epoch 499, loss with penalty 2.764890670776367
# epoch 500, loss with penalty 2.7647783756256104
# New min loss = tensor([2.7645], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7635], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7624], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7614], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7603], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7593], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7582], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7571], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7561], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7551], grad_fn=<AddBackward0>)
# epoch 599, loss with penalty 2.754700183868408
# epoch 600, loss with penalty 2.7546093463897705
# New min loss = tensor([2.7540], grad_fn=<AddBackward0>)
# epoch 699, loss with penalty 2.7957370281219482
# epoch 700, loss with penalty 2.8082146644592285
# epoch 799, loss with penalty 2.7556090354919434
# epoch 800, loss with penalty 2.7554702758789062
# New min loss = tensor([2.7530], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7519], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7508], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7498], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7487], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7476], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7466], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7456], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7445], grad_fn=<AddBackward0>)
# epoch 899, loss with penalty 2.744305372238159
# epoch 900, loss with penalty 2.7442078590393066
# New min loss = tensor([2.7434], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7424], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7414], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7403], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7393], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7383], grad_fn=<AddBackward0>)
# epoch 999, loss with penalty 2.886685848236084
# epoch 1000, loss with penalty 4.60153865814209
# epoch 1099, loss with penalty 2.747617244720459
# epoch 1100, loss with penalty 2.7473857402801514
# New min loss = tensor([2.7372], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7361], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7350], grad_fn=<AddBackward0>)
# epoch 1199, loss with penalty 2.7342453002929688
# epoch 1200, loss with penalty 2.734140396118164
# New min loss = tensor([2.7339], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7329], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7318], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7307], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7297], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7286], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7276], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7266], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7255], grad_fn=<AddBackward0>)
# epoch 1299, loss with penalty 2.7254836559295654
# epoch 1300, loss with penalty 2.7257800102233887
# epoch 1399, loss with penalty 2.7350876331329346
# epoch 1400, loss with penalty 2.7357420921325684
# New min loss = tensor([2.7245], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7234], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7224], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7213], grad_fn=<AddBackward0>)
# epoch 1499, loss with penalty 2.720465660095215
# epoch 1500, loss with penalty 2.720365047454834
# New min loss = tensor([2.7203], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7192], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7182], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7171], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7160], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7150], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7140], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7129], grad_fn=<AddBackward0>)
# epoch 1599, loss with penalty 3.6832008361816406
# epoch 1600, loss with penalty 4.656241416931152
# epoch 1699, loss with penalty 2.7187161445617676
# epoch 1700, loss with penalty 2.718738555908203
# New min loss = tensor([2.7119], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7108], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7098], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7087], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7077], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7066], grad_fn=<AddBackward0>)
# epoch 1799, loss with penalty 2.70651912689209
# epoch 1800, loss with penalty 2.706413745880127
# New min loss = tensor([2.7056], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7046], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7035], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7024], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7014], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7004], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6994], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6983], grad_fn=<AddBackward0>)
# epoch 1899, loss with penalty 2.757413148880005
# epoch 1900, loss with penalty 2.805701971054077
# epoch 1999, loss with penalty 2.7016735076904297
# epoch 2000, loss with penalty 2.7013328075408936
# New min loss = tensor([2.6973], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6962], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6952], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6941], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6931], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6921], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6910], grad_fn=<AddBackward0>)
# epoch 2099, loss with penalty 2.6904242038726807
# epoch 2100, loss with penalty 2.690329074859619
# New min loss = tensor([2.6899], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6889], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6879], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6868], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6858], grad_fn=<AddBackward0>)
# epoch 2199, loss with penalty 3.2525088787078857
# epoch 2200, loss with penalty 3.0992672443389893
# New min loss = tensor([2.6848], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6838], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6827], grad_fn=<AddBackward0>)
# epoch 2299, loss with penalty 2.6824376583099365
# epoch 2300, loss with penalty 2.68233585357666
# New min loss = tensor([2.6817], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6806], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6796], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6786], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6775], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6765], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6755], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6745], grad_fn=<AddBackward0>)
# epoch 2399, loss with penalty 2.6738507747650146
# epoch 2400, loss with penalty 2.6737782955169678
# epoch 2499, loss with penalty 2.6826841831207275
# epoch 2500, loss with penalty 2.6807711124420166
# New min loss = tensor([2.6735], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6724], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6714], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6703], grad_fn=<AddBackward0>)
# epoch 2599, loss with penalty 2.669440984725952
# epoch 2600, loss with penalty 2.669362783432007
# New min loss = tensor([2.6693], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6682], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6672], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6662], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6651], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6641], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6631], grad_fn=<AddBackward0>)
# epoch 2699, loss with penalty 2.6628077030181885
# epoch 2700, loss with penalty 2.662757635116577
# epoch 2799, loss with penalty 2.6659600734710693
# epoch 2800, loss with penalty 2.666330575942993
# New min loss = tensor([2.6620], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6610], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6600], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6589], grad_fn=<AddBackward0>)
# epoch 2899, loss with penalty 2.6579720973968506
# New min loss = tensor([2.6579], grad_fn=<AddBackward0>)
# epoch 2900, loss with penalty 2.657926082611084
# New min loss = tensor([2.6569], grad_fn=<AddBackward0>)
# epoch 2999, loss with penalty 2.6953632831573486
# epoch 3000, loss with penalty 2.672844409942627
# New min loss = tensor([2.6559], grad_fn=<AddBackward0>)
# epoch 3099, loss with penalty 2.655200242996216
# epoch 3100, loss with penalty 2.655158519744873
# New min loss = tensor([2.6549], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6539], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6528], grad_fn=<AddBackward0>)
# epoch 3199, loss with penalty 3.2189409732818604
# epoch 3200, loss with penalty 3.52581787109375
# epoch 3299, loss with penalty 2.653491973876953
# epoch 3300, loss with penalty 2.6533448696136475
# New min loss = tensor([2.6518], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6508], grad_fn=<AddBackward0>)
# epoch 3399, loss with penalty 2.6500003337860107
# epoch 3400, loss with penalty 2.649976968765259
# New min loss = tensor([2.6498], grad_fn=<AddBackward0>)
# epoch 3499, loss with penalty 2.657001495361328
# epoch 3500, loss with penalty 2.6579837799072266
# epoch 3599, loss with penalty 2.6490440368652344
# epoch 3600, loss with penalty 2.649019956588745
# New min loss = tensor([2.6488], grad_fn=<AddBackward0>)
# epoch 3699, loss with penalty 2.7563092708587646
# epoch 3700, loss with penalty 2.666377544403076
# epoch 3799, loss with penalty 2.647934913635254
# epoch 3800, loss with penalty 2.6479105949401855
# New min loss = tensor([2.6478], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6468], grad_fn=<AddBackward0>)
# epoch 3899, loss with penalty 5.860262870788574
# epoch 3900, loss with penalty 5.589076042175293
# epoch 3999, loss with penalty 2.6470580101013184
# epoch 4000, loss with penalty 2.6469976902008057
# New min loss = tensor([2.6457], grad_fn=<AddBackward0>)
# epoch 4099, loss with penalty 2.645174264907837
# epoch 4100, loss with penalty 2.6451575756073
# epoch 4199, loss with penalty 2.6475563049316406
# epoch 4200, loss with penalty 2.647663116455078
# New min loss = tensor([2.6447], grad_fn=<AddBackward0>)
# epoch 4299, loss with penalty 2.644695520401001
# epoch 4300, loss with penalty 2.6446826457977295
# epoch 4399, loss with penalty 2.6792120933532715
# epoch 4400, loss with penalty 2.701566219329834
# epoch 4499, loss with penalty 2.6442222595214844
# epoch 4500, loss with penalty 2.644278049468994
# New min loss = tensor([2.6437], grad_fn=<AddBackward0>)
# epoch 4599, loss with penalty 2.64310359954834
# epoch 4600, loss with penalty 2.6431047916412354
# epoch 4699, loss with penalty 2.6436259746551514
# epoch 4700, loss with penalty 2.6437270641326904
# New min loss = tensor([2.6427], grad_fn=<AddBackward0>)
# epoch 4799, loss with penalty 2.6426563262939453
# epoch 4800, loss with penalty 2.642653465270996
# epoch 4899, loss with penalty 2.6471381187438965
# epoch 4900, loss with penalty 2.6449549198150635
# epoch 4999, loss with penalty 2.6425204277038574
# epoch 5000, loss with penalty 2.642515182495117
# epoch 5099, loss with penalty 3.2771618366241455
# epoch 5100, loss with penalty 3.133145332336426
# epoch 5199, loss with penalty 2.6423816680908203
# epoch 5200, loss with penalty 2.642368793487549
# epoch 5299, loss with penalty 3.315141439437866
# epoch 5300, loss with penalty 2.7815167903900146
# epoch 5399, loss with penalty 2.642268657684326
# epoch 5400, loss with penalty 2.642277240753174
# epoch 5499, loss with penalty 3.4904885292053223
# epoch 5500, loss with penalty 3.75510835647583
# epoch 5599, loss with penalty 2.6421942710876465
# epoch 5600, loss with penalty 2.642199754714966
# epoch 5699, loss with penalty 2.6434545516967773
# epoch 5700, loss with penalty 2.644383668899536
# epoch 5799, loss with penalty 2.6421759128570557
# epoch 5800, loss with penalty 2.6421775817871094
# epoch 5899, loss with penalty 2.6420769691467285
# epoch 5900, loss with penalty 2.6421825885772705
# epoch 5999, loss with penalty 2.642143726348877
# epoch 6000, loss with penalty 2.642141580581665
# epoch 6099, loss with penalty 2.6459996700286865
# epoch 6100, loss with penalty 2.6483819484710693
# epoch 6199, loss with penalty 2.6421709060668945
# epoch 6200, loss with penalty 2.642164707183838
# epoch 6299, loss with penalty 2.9433181285858154
# epoch 6300, loss with penalty 3.224670886993408
# epoch 6399, loss with penalty 2.641986608505249
# epoch 6400, loss with penalty 2.64198899269104
# epoch 6499, loss with penalty 3.153082847595215
# epoch 6500, loss with penalty 3.331300973892212
# epoch 6599, loss with penalty 2.641944169998169
# epoch 6600, loss with penalty 2.6419458389282227
# epoch 6699, loss with penalty 2.6642229557037354
# epoch 6700, loss with penalty 2.6560239791870117
# epoch 6799, loss with penalty 2.6418957710266113
# epoch 6800, loss with penalty 2.641897439956665
# epoch 6899, loss with penalty 2.6631667613983154
# epoch 6900, loss with penalty 2.6583971977233887
# epoch 6999, loss with penalty 2.641839027404785
# epoch 7000, loss with penalty 2.64184308052063
# epoch 7099, loss with penalty 2.642333745956421
# epoch 7100, loss with penalty 2.64216947555542
# epoch 7199, loss with penalty 2.646714448928833
# epoch 7200, loss with penalty 2.646289348602295
# epoch 7299, loss with penalty 2.642930507659912
# epoch 7300, loss with penalty 2.6435863971710205
# epoch 7399, loss with penalty 2.643810749053955
# epoch 7400, loss with penalty 2.6477596759796143
# epoch 7499, loss with penalty 2.7057862281799316
# epoch 7500, loss with penalty 2.7363836765289307
# epoch 7599, loss with penalty 2.9453682899475098
# epoch 7600, loss with penalty 2.957453727722168
# epoch 7699, loss with penalty 2.643315315246582
# epoch 7700, loss with penalty 2.6428611278533936
# epoch 7799, loss with penalty 2.668442487716675
# epoch 7800, loss with penalty 2.6694889068603516
# epoch 7899, loss with penalty 2.7410521507263184
# epoch 7900, loss with penalty 2.674882173538208
# epoch 7999, loss with penalty 2.702127456665039
# epoch 8000, loss with penalty 2.689344882965088
# epoch 8099, loss with penalty 2.6495494842529297
# epoch 8100, loss with penalty 2.6514317989349365
# epoch 8199, loss with penalty 2.642719268798828
# epoch 8200, loss with penalty 2.643073081970215
# epoch 8299, loss with penalty 2.642378091812134
# epoch 8300, loss with penalty 2.64253306388855
# epoch 8399, loss with penalty 2.8596913814544678
# epoch 8400, loss with penalty 2.9139533042907715
# epoch 8499, loss with penalty 2.667743444442749
# epoch 8500, loss with penalty 2.6499876976013184
# epoch 8599, loss with penalty 2.6565794944763184
# epoch 8600, loss with penalty 2.6557977199554443
# epoch 8699, loss with penalty 2.6677091121673584
# epoch 8700, loss with penalty 2.6658883094787598
# epoch 8799, loss with penalty 2.6525936126708984
# epoch 8800, loss with penalty 2.646261692047119
# New min loss = tensor([2.6417], grad_fn=<AddBackward0>)
# epoch 8899, loss with penalty 2.643364667892456
# epoch 8900, loss with penalty 2.642551898956299
# epoch 8999, loss with penalty 2.740753412246704
# epoch 9000, loss with penalty 2.7526252269744873
# epoch 9099, loss with penalty 535.7255859375
# epoch 9100, loss with penalty 762.639892578125
# epoch 9199, loss with penalty 9.769779205322266
# epoch 9200, loss with penalty 9.758408546447754
# epoch 9299, loss with penalty 8.57395076751709
# epoch 9300, loss with penalty 8.56213665008545
# epoch 9399, loss with penalty 7.410717964172363
# epoch 9400, loss with penalty 7.3993377685546875
# epoch 9499, loss with penalty 6.313045024871826
# epoch 9500, loss with penalty 6.302602767944336
# epoch 9599, loss with penalty 5.347618579864502
# epoch 9600, loss with penalty 5.338888645172119
# epoch 9699, loss with penalty 4.581509590148926
# epoch 9700, loss with penalty 4.574954509735107
# epoch 9799, loss with penalty 4.028946876525879
# epoch 9800, loss with penalty 4.024393558502197
# epoch 9899, loss with penalty 3.652446746826172
# epoch 9900, loss with penalty 3.6493899822235107
# epoch 9999, loss with penalty 3.3998804092407227
# epoch 10000, loss with penalty 3.3978240489959717
# epoch 10099, loss with penalty 3.228375196456909
# epoch 10100, loss with penalty 3.2269625663757324
# epoch 10199, loss with penalty 3.10892391204834
# epoch 10200, loss with penalty 3.107919931411743
# epoch 10299, loss with penalty 3.023264169692993
# epoch 10300, loss with penalty 3.0225374698638916
# epoch 10399, loss with penalty 2.9601097106933594
# epoch 10400, loss with penalty 2.9595677852630615
# epoch 10499, loss with penalty 2.912379741668701
# epoch 10500, loss with penalty 2.911961793899536
# epoch 10599, loss with penalty 2.875521421432495
# epoch 10600, loss with penalty 2.8751978874206543
# epoch 10699, loss with penalty 2.8465378284454346
# epoch 10700, loss with penalty 2.8462796211242676
# epoch 10799, loss with penalty 2.8233702182769775
# epoch 10800, loss with penalty 2.823162078857422
# epoch 10899, loss with penalty 2.8045835494995117
# epoch 10900, loss with penalty 2.8044137954711914
# epoch 10999, loss with penalty 2.7891430854797363
# epoch 11000, loss with penalty 2.7890050411224365
# epoch 11099, loss with penalty 2.7762889862060547
# epoch 11100, loss with penalty 2.7761693000793457
# epoch 11199, loss with penalty 2.7654502391815186
# epoch 11200, loss with penalty 2.7653512954711914
# epoch 11299, loss with penalty 2.7562029361724854
# epoch 11300, loss with penalty 2.756117582321167
# epoch 11399, loss with penalty 2.7482151985168457
# epoch 11400, loss with penalty 2.748140335083008
# epoch 11499, loss with penalty 2.7412261962890625
# epoch 11500, loss with penalty 2.7411625385284424
# epoch 11599, loss with penalty 2.7350363731384277
# epoch 11600, loss with penalty 2.7349796295166016
# epoch 11699, loss with penalty 2.7294909954071045
# epoch 11700, loss with penalty 2.7294390201568604
# epoch 11799, loss with penalty 2.7244603633880615
# epoch 11800, loss with penalty 2.724412202835083
# epoch 11899, loss with penalty 2.719853162765503
# epoch 11900, loss with penalty 2.7198076248168945
# epoch 11999, loss with penalty 2.715592622756958
# epoch 12000, loss with penalty 2.715552806854248
# epoch 12099, loss with penalty 2.711623430252075
# epoch 12100, loss with penalty 2.711585521697998
# epoch 12199, loss with penalty 2.7078981399536133
# epoch 12200, loss with penalty 2.7078628540039062
# epoch 12299, loss with penalty 2.704387903213501
# epoch 12300, loss with penalty 2.704352855682373
# epoch 12399, loss with penalty 2.7010600566864014
# epoch 12400, loss with penalty 2.7010297775268555
# epoch 12499, loss with penalty 2.6979024410247803
# epoch 12500, loss with penalty 2.6978721618652344
# epoch 12599, loss with penalty 2.694896697998047
# epoch 12600, loss with penalty 2.6948671340942383
# epoch 12699, loss with penalty 2.6920320987701416
# epoch 12700, loss with penalty 2.6920042037963867
# epoch 12799, loss with penalty 2.6893022060394287
# epoch 12800, loss with penalty 2.689272880554199
# epoch 12899, loss with penalty 2.686697483062744
# epoch 12900, loss with penalty 2.6866719722747803
# epoch 12999, loss with penalty 2.6842164993286133
# epoch 13000, loss with penalty 2.684192180633545
# epoch 13099, loss with penalty 2.681856155395508
# epoch 13100, loss with penalty 2.6818313598632812
# epoch 13199, loss with penalty 2.6796011924743652
# epoch 13200, loss with penalty 2.679582118988037
# epoch 13299, loss with penalty 2.6774630546569824
# epoch 13300, loss with penalty 2.6774423122406006
# epoch 13399, loss with penalty 2.6754302978515625
# epoch 13400, loss with penalty 2.6754097938537598
# epoch 13499, loss with penalty 2.673497438430786
# epoch 13500, loss with penalty 2.673480272293091
# epoch 13599, loss with penalty 2.6716697216033936
# epoch 13600, loss with penalty 2.6716508865356445
# epoch 13699, loss with penalty 2.6699349880218506
# epoch 13700, loss with penalty 2.6699185371398926
# epoch 13799, loss with penalty 2.6682941913604736
# epoch 13800, loss with penalty 2.6682777404785156
# epoch 13899, loss with penalty 2.6667463779449463
# epoch 13900, loss with penalty 2.666731834411621
# epoch 13999, loss with penalty 2.665285587310791
# epoch 14000, loss with penalty 2.6652708053588867
# epoch 14099, loss with penalty 2.663910388946533
# epoch 14100, loss with penalty 2.6638946533203125
# epoch 14199, loss with penalty 2.662614107131958
# epoch 14200, loss with penalty 2.6626007556915283
# epoch 14299, loss with penalty 2.661393642425537
# epoch 14300, loss with penalty 2.6613810062408447
# epoch 14399, loss with penalty 6.095704078674316
# epoch 14400, loss with penalty 5.1899094581604
# epoch 14499, loss with penalty 2.6672415733337402
# epoch 14500, loss with penalty 2.666994094848633
# epoch 14599, loss with penalty 2.6594998836517334
# epoch 14600, loss with penalty 2.6594743728637695
# epoch 14699, loss with penalty 2.657769203186035
# epoch 14700, loss with penalty 2.657757043838501
# epoch 14799, loss with penalty 3.162950038909912
# epoch 14800, loss with penalty 3.558911085128784
# epoch 14899, loss with penalty 2.660632848739624
# epoch 14900, loss with penalty 2.660475969314575
# epoch 14999, loss with penalty 2.6553688049316406
# Using potential function defined as class takes 4752.70396900177
# Before normalization:
# tensor([[-0.0546,  0.0462, -0.0031,  0.0224,  0.0377, -0.0306,  0.0491, -0.0417,
#           0.0855,  0.0200, -0.0259,  0.0485,  0.1136,  0.1685,  0.1035, -0.1541,
#           0.0170, -0.0679,  0.0322, -0.0814,  0.0891, -0.0132,  0.0083, -0.0051,
#           0.1743,  0.0419,  0.0312, -0.0634, -0.0394, -0.1496, -0.0944,  0.0218,
#          -0.0054,  0.0543, -0.0439,  0.0099, -0.0365,  0.1551,  0.1153,  0.0104,
#           0.0471,  0.0021, -0.0577,  0.0131, -0.0988, -0.0239,  0.0876, -0.0033,
#           0.0102, -0.0578, -0.0787,  0.0237, -0.0153, -0.0270, -0.0822,  0.0308,
#          -0.0105,  0.0489,  0.0031,  0.0314]])
# tensor([-0.0404])
# After normalization:
# tensor([[-0.0546,  0.0463, -0.0031,  0.0225,  0.0377, -0.0306,  0.0491, -0.0418,
#           0.0855,  0.0200, -0.0259,  0.0485,  0.1137,  0.1686,  0.1036, -0.1542,
#           0.0170, -0.0679,  0.0322, -0.0814,  0.0892, -0.0133,  0.0084, -0.0051,
#           0.1744,  0.0419,  0.0312, -0.0634, -0.0394, -0.1497, -0.0945,  0.0218,
#          -0.0054,  0.0544, -0.0440,  0.0099, -0.0366,  0.1552,  0.1154,  0.0104,
#           0.0472,  0.0021, -0.0578,  0.0131, -0.0989, -0.0239,  0.0877, -0.0033,
#           0.0102, -0.0579, -0.0788,  0.0237, -0.0153, -0.0270, -0.0822,  0.0308,
#          -0.0105,  0.0489,  0.0031,  0.0315]])
# tensor([-0.0404])
# c value = tensor([1.0007], grad_fn=<MulBackward0>)
# Before normalization:
# tensor([[ 1.3666e-04,  6.3481e-05, -2.3653e-04, -2.2158e-04, -2.4269e-04,
#           8.4786e-05, -1.0683e-05,  5.3069e-04, -3.5554e-05,  6.2050e-04,
#           1.0385e-01,  1.2059e-03,  4.7475e-04,  1.1636e-01, -6.7251e-02,
#          -2.6470e-02, -3.5292e-06,  1.5308e-03, -2.2370e-04, -8.8529e-05,
#          -2.1330e-02, -3.4358e-04,  6.7952e-04,  9.1071e-07, -4.1529e-04,
#           1.4259e-04, -2.8242e-04,  1.1112e-03,  2.1220e-04, -4.5364e-02,
#           1.4553e-03,  4.9113e-04, -1.2888e-04, -3.8755e-04, -7.5811e-04,
#          -8.1307e-04,  1.6345e-04,  1.0950e-01, -9.8860e-04, -1.4818e-04,
#           2.5785e-04, -4.4310e-04,  1.9394e-04,  7.7639e-04,  8.3030e-02,
#           4.3903e-05, -3.8188e-05,  7.0239e-05, -1.0647e-03,  2.6744e-04,
#          -1.9088e-04, -2.6904e-04, -2.9393e-05,  9.6115e-04,  1.7651e-04,
#           6.8078e-05,  2.8744e-02,  1.5887e-04,  1.9238e-04,  1.3235e-04]])
# tensor([0.1431])
# After normalization:
# tensor([[ 1.3674e-04,  6.3519e-05, -2.3668e-04, -2.2171e-04, -2.4284e-04,
#           8.4837e-05, -1.0690e-05,  5.3101e-04, -3.5576e-05,  6.2088e-04,
#           1.0392e-01,  1.2066e-03,  4.7504e-04,  1.1643e-01, -6.7291e-02,
#          -2.6486e-02, -3.5314e-06,  1.5317e-03, -2.2383e-04, -8.8582e-05,
#          -2.1343e-02, -3.4379e-04,  6.7993e-04,  9.1126e-07, -4.1554e-04,
#           1.4268e-04, -2.8259e-04,  1.1119e-03,  2.1233e-04, -4.5392e-02,
#           1.4562e-03,  4.9142e-04, -1.2896e-04, -3.8779e-04, -7.5857e-04,
#          -8.1356e-04,  1.6355e-04,  1.0956e-01, -9.8920e-04, -1.4827e-04,
#           2.5800e-04, -4.4336e-04,  1.9405e-04,  7.7686e-04,  8.3080e-02,
#           4.3929e-05, -3.8211e-05,  7.0281e-05, -1.0654e-03,  2.6760e-04,
#          -1.9100e-04, -2.6920e-04, -2.9410e-05,  9.6173e-04,  1.7662e-04,
#           6.8119e-05,  2.8761e-02,  1.5896e-04,  1.9249e-04,  1.3243e-04]])
# tensor([0.1432])
# c value = tensor([1.0006], grad_fn=<MulBackward0>)

# %%
del model_21_sin
del adam_opt_21_sin

model_21_sin = Nonlinear_2(layer_width=60, use_sin=True)
adam_opt_21_sin = torch.optim.Adam(model_21_sin.parameters(), 
                                    lr=learningRate, 
                                    betas=(0.9, 0.999), 
                                    eps=1e-08, 
                                    weight_decay=0, 
                                    amsgrad=False)

res2_21_sin = auto_test_documentation(model_21_sin, adam_opt_21_sin, p_fn4, 
                                      model_name='model_21_sin_pfn4',
                                      res_path=RESULT_PATH,
                                      loss_fname='loss_21_sin_pfn4',
                                      loss_with_pen_fname = 'loss_pen_21_sin_pfn4')
# Out:
# Start time is 2022-08-10 03:30:12.641696-04:00
# Initiate first min loss = tensor([9.0097], grad_fn=<AddBackward0>)
# epoch 0, loss with penalty 9.009729385375977
# New min loss = tensor([3.9205], grad_fn=<AddBackward0>)
# New min loss = tensor([3.8219], grad_fn=<AddBackward0>)
# New min loss = tensor([3.5630], grad_fn=<AddBackward0>)
# New min loss = tensor([3.3993], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2397], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2300], grad_fn=<AddBackward0>)
# New min loss = tensor([3.2249], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1974], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1756], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1571], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1424], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1244], grad_fn=<AddBackward0>)
# epoch 99, loss with penalty 3.15636944770813
# epoch 100, loss with penalty 3.1528680324554443
# New min loss = tensor([3.1203], grad_fn=<AddBackward0>)
# New min loss = tensor([3.1022], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0885], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0852], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0761], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0659], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0612], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0502], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0472], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0438], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0349], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0293], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0257], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0189], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0126], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0099], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0075], grad_fn=<AddBackward0>)
# New min loss = tensor([3.0022], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9963], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9925], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9898], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9854], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9799], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9756], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9724], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9684], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9634], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9590], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9555], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9516], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9469], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9425], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9387], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9348], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9304], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9260], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9221], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9182], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9139], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9096], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9056], grad_fn=<AddBackward0>)
# New min loss = tensor([2.9017], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8975], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8933], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8893], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8853], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8812], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8770], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8730], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8690], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8649], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8608], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8568], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8529], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8488], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8448], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8408], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8368], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8328], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8288], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8249], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8209], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8169], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8130], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8091], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8051], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8012], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7973], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7934], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7895], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7856], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7817], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7779], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7740], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7702], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7663], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7625], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7587], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7549], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7511], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7473], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7436], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7398], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7360], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7323], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7286], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7249], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7212], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7175], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7138], grad_fn=<AddBackward0>)
# epoch 199, loss with penalty 2.7137808799743652
# New min loss = tensor([2.7101], grad_fn=<AddBackward0>)
# epoch 200, loss with penalty 2.7101142406463623
# New min loss = tensor([2.7065], grad_fn=<AddBackward0>)
# New min loss = tensor([2.7028], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6992], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6956], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6919], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6883], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6848], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6812], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6776], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6741], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6706], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6670], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6635], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6600], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6566], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6531], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6496], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6462], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6428], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6393], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6359], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6326], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6292], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6258], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6225], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6191], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6158], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6125], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6092], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6059], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6027], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5994], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5962], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5930], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5898], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5866], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5834], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5802], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5771], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5739], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5708], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5677], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5646], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5615], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5585], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5554], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5524], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5494], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5464], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5434], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5404], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5374], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5345], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5316], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5286], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5257], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5229], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5200], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5171], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5143], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5114], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5086], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5058], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5030], grad_fn=<AddBackward0>)
# New min loss = tensor([2.5003], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4975], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4948], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4921], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4893], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4866], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4840], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4813], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4786], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4760], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4734], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4708], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4682], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4656], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4630], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4605], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4579], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4554], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4529], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4504], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4479], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4455], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4430], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4406], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4381], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4357], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4333], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4310], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4286], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4262], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4239], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4216], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4193], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4170], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4147], grad_fn=<AddBackward0>)
# epoch 299, loss with penalty 2.414677858352661
# New min loss = tensor([2.4124], grad_fn=<AddBackward0>)
# epoch 300, loss with penalty 2.4124088287353516
# New min loss = tensor([2.4102], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4079], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4057], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4035], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4013], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3991], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3969], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3947], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3926], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3905], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3883], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3862], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3841], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3821], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3800], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3779], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3759], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3739], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3719], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3699], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3679], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3659], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3639], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3620], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3600], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3581], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3562], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3543], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3524], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3505], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3487], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3468], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3450], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3432], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3413], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3395], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3378], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3360], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3342], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3325], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3307], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3290], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3273], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3256], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3239], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3222], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3205], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3188], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3172], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3156], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3139], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3123], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3107], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3091], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3075], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3059], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3044], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3028], grad_fn=<AddBackward0>)
# New min loss = tensor([2.3013], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2998], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2982], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2967], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2952], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2937], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2923], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2908], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2893], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2879], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2865], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2850], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2836], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2822], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2808], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2794], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2781], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2767], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2753], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2740], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2726], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2713], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2700], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2687], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2674], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2661], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2648], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2635], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2623], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2610], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2598], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2585], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2573], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2561], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2549], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2536], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2525], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2513], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2501], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2489], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2478], grad_fn=<AddBackward0>)
# epoch 399, loss with penalty 2.247755765914917
# New min loss = tensor([2.2466], grad_fn=<AddBackward0>)
# epoch 400, loss with penalty 2.2466025352478027
# New min loss = tensor([2.2455], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2443], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2432], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2421], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2410], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2399], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2388], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2377], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2366], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2355], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2344], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2334], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2323], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2313], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2303], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2292], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2282], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2272], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2262], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2252], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2232], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2213], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2193], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2174], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2156], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2137], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2119], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2101], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2083], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2066], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2049], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2032], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2015], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1999], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1982], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1966], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1951], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1935], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1920], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1904], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1890], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1875], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1860], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1846], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1832], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1818], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1804], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1790], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1777], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1764], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1751], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1738], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1725], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1712], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1700], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1688], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1676], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1664], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1652], grad_fn=<AddBackward0>)
# epoch 499, loss with penalty 2.164593458175659
# New min loss = tensor([2.1640], grad_fn=<AddBackward0>)
# epoch 500, loss with penalty 2.1640148162841797
# New min loss = tensor([2.1629], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1617], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1606], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1595], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1584], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1573], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1563], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1552], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1542], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1531], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1521], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1511], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1496], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1482], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1467], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1453], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1439], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1426], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1412], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1399], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1386], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1374], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1361], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1349], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1336], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1325], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1313], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1301], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1290], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1278], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1267], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1256], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1246], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1235], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1225], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1214], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1204], grad_fn=<AddBackward0>)
# epoch 599, loss with penalty 2.12042236328125
# epoch 600, loss with penalty 2.120086908340454
# New min loss = tensor([2.1194], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1181], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1168], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1155], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1143], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1131], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1119], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1107], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1095], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1084], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1073], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1062], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1051], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1040], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1029], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1019], grad_fn=<AddBackward0>)
# New min loss = tensor([2.1009], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0999], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0986], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0974], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0962], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0951], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0939], grad_fn=<AddBackward0>)
# epoch 699, loss with penalty 2.093017578125
# New min loss = tensor([2.0928], grad_fn=<AddBackward0>)
# epoch 700, loss with penalty 2.0927929878234863
# New min loss = tensor([2.0917], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0906], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0895], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0885], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0875], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0864], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0852], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0841], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0829], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0818], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0807], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0796], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0786], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0775], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0765], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0754], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0743], grad_fn=<AddBackward0>)
# epoch 799, loss with penalty 2.0740952491760254
# epoch 800, loss with penalty 2.0739352703094482
# New min loss = tensor([2.0732], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0721], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0710], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0700], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0690], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0679], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0668], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0657], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0647], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0637], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0626], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0615], grad_fn=<AddBackward0>)
# epoch 899, loss with penalty 2.0606117248535156
# New min loss = tensor([2.0605], grad_fn=<AddBackward0>)
# epoch 900, loss with penalty 2.0604989528656006
# New min loss = tensor([2.0595], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0584], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0574], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0564], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0553], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0543], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0532], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0522], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0511], grad_fn=<AddBackward0>)
# epoch 999, loss with penalty 2.050995349884033
# epoch 1000, loss with penalty 2.0509142875671387
# New min loss = tensor([2.0500], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0490], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0480], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0469], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0459], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0448], grad_fn=<AddBackward0>)
# epoch 1099, loss with penalty 2.044109582901001
# epoch 1100, loss with penalty 2.044055700302124
# New min loss = tensor([2.0438], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0427], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0417], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0406], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0396], grad_fn=<AddBackward0>)
# epoch 1199, loss with penalty 2.0390963554382324
# epoch 1200, loss with penalty 2.0390517711639404
# New min loss = tensor([2.0386], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0376], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0366], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0355], grad_fn=<AddBackward0>)
# epoch 1299, loss with penalty 2.035301923751831
# epoch 1300, loss with penalty 2.0352699756622314
# New min loss = tensor([2.0345], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0335], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0325], grad_fn=<AddBackward0>)
# epoch 1399, loss with penalty 2.0322959423065186
# epoch 1400, loss with penalty 2.0322694778442383
# New min loss = tensor([2.0315], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0305], grad_fn=<AddBackward0>)
# epoch 1499, loss with penalty 2.0297789573669434
# epoch 1500, loss with penalty 2.029756784439087
# New min loss = tensor([2.0295], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0284], grad_fn=<AddBackward0>)
# epoch 1599, loss with penalty 2.0275700092315674
# epoch 1600, loss with penalty 2.02754807472229
# New min loss = tensor([2.0274], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0264], grad_fn=<AddBackward0>)
# epoch 1699, loss with penalty 16.63822364807129
# epoch 1700, loss with penalty 24.224056243896484
# epoch 1799, loss with penalty 2.0269980430603027
# epoch 1800, loss with penalty 2.026933193206787
# New min loss = tensor([2.0254], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0243], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0233], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0223], grad_fn=<AddBackward0>)
# epoch 1899, loss with penalty 2.02207612991333
# epoch 1900, loss with penalty 2.022043466567993
# New min loss = tensor([2.0213], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0202], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0192], grad_fn=<AddBackward0>)
# epoch 1999, loss with penalty 2.0191168785095215
# epoch 2000, loss with penalty 2.0190887451171875
# New min loss = tensor([2.0182], grad_fn=<AddBackward0>)
# epoch 2099, loss with penalty 2.0494420528411865
# epoch 2100, loss with penalty 2.2266955375671387
# New min loss = tensor([2.0171], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0160], grad_fn=<AddBackward0>)
# epoch 2199, loss with penalty 2.0152673721313477
# epoch 2200, loss with penalty 2.0152111053466797
# New min loss = tensor([2.0150], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0140], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0129], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0119], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0109], grad_fn=<AddBackward0>)
# epoch 2299, loss with penalty 2.010885238647461
# epoch 2300, loss with penalty 2.010850429534912
# New min loss = tensor([2.0099], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0089], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0078], grad_fn=<AddBackward0>)
# epoch 2399, loss with penalty 2.0075623989105225
# epoch 2400, loss with penalty 2.0075314044952393
# New min loss = tensor([2.0068], grad_fn=<AddBackward0>)
# epoch 2499, loss with penalty 2.07134747505188
# epoch 2500, loss with penalty 2.0135788917541504
# New min loss = tensor([2.0057], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0047], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0036], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0026], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0016], grad_fn=<AddBackward0>)
# epoch 2599, loss with penalty 2.0014472007751465
# epoch 2600, loss with penalty 2.0013864040374756
# New min loss = tensor([2.0005], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9995], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9985], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9975], grad_fn=<AddBackward0>)
# epoch 2699, loss with penalty 1.9965852499008179
# epoch 2700, loss with penalty 1.99654221534729
# New min loss = tensor([1.9965], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9954], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9944], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9934], grad_fn=<AddBackward0>)
# epoch 2799, loss with penalty 1.992705225944519
# epoch 2800, loss with penalty 1.9926677942276
# New min loss = tensor([1.9924], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9913], grad_fn=<AddBackward0>)
# epoch 2899, loss with penalty 2.027726173400879
# epoch 2900, loss with penalty 2.3111178874969482
# New min loss = tensor([1.9899], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9887], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9877], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9867], grad_fn=<AddBackward0>)
# epoch 2999, loss with penalty 1.9863804578781128
# epoch 3000, loss with penalty 1.9863146543502808
# New min loss = tensor([1.9856], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9846], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9835], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9825], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9815], grad_fn=<AddBackward0>)
# epoch 3099, loss with penalty 1.9809476137161255
# epoch 3100, loss with penalty 1.980903148651123
# New min loss = tensor([1.9805], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9794], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9784], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9774], grad_fn=<AddBackward0>)
# epoch 3199, loss with penalty 1.9768931865692139
# epoch 3200, loss with penalty 1.9768561124801636
# New min loss = tensor([1.9764], grad_fn=<AddBackward0>)
# epoch 3299, loss with penalty 1.9982421398162842
# epoch 3300, loss with penalty 1.9927912950515747
# New min loss = tensor([1.9754], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9743], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9733], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9723], grad_fn=<AddBackward0>)
# epoch 3399, loss with penalty 1.971877098083496
# epoch 3400, loss with penalty 1.971821665763855
# New min loss = tensor([1.9713], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9702], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9692], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9682], grad_fn=<AddBackward0>)
# epoch 3499, loss with penalty 1.9674919843673706
# epoch 3500, loss with penalty 1.9674559831619263
# New min loss = tensor([1.9672], grad_fn=<AddBackward0>)
# epoch 3599, loss with penalty 2.0935888290405273
# epoch 3600, loss with penalty 1.9896048307418823
# New min loss = tensor([1.9661], grad_fn=<AddBackward0>)
# epoch 3699, loss with penalty 1.9655183553695679
# epoch 3700, loss with penalty 1.9654587507247925
# New min loss = tensor([1.9651], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9640], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9630], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9620], grad_fn=<AddBackward0>)
# epoch 3799, loss with penalty 1.9612717628479004
# epoch 3800, loss with penalty 1.9612423181533813
# New min loss = tensor([1.9610], grad_fn=<AddBackward0>)
# epoch 3899, loss with penalty 2.147841453552246
# epoch 3900, loss with penalty 1.9938428401947021
# epoch 3999, loss with penalty 1.9607285261154175
# epoch 4000, loss with penalty 1.9606674909591675
# New min loss = tensor([1.9600], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9590], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9579], grad_fn=<AddBackward0>)
# epoch 4099, loss with penalty 1.9572256803512573
# epoch 4100, loss with penalty 1.9572056531906128
# New min loss = tensor([1.9569], grad_fn=<AddBackward0>)
# epoch 4199, loss with penalty 2.042266368865967
# epoch 4200, loss with penalty 2.0634703636169434
# epoch 4299, loss with penalty 1.9569791555404663
# epoch 4300, loss with penalty 1.956935167312622
# New min loss = tensor([1.9559], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9549], grad_fn=<AddBackward0>)
# epoch 4399, loss with penalty 1.9544838666915894
# epoch 4400, loss with penalty 1.954468011856079
# epoch 4499, loss with penalty 1.9681023359298706
# epoch 4500, loss with penalty 1.9611563682556152
# epoch 4599, loss with penalty 1.9539381265640259
# New min loss = tensor([1.9539], grad_fn=<AddBackward0>)
# epoch 4600, loss with penalty 1.953913688659668
# New min loss = tensor([1.9529], grad_fn=<AddBackward0>)
# epoch 4699, loss with penalty 2.084799289703369
# epoch 4700, loss with penalty 2.1801419258117676
# epoch 4799, loss with penalty 1.9557417631149292
# epoch 4800, loss with penalty 1.9556833505630493
# epoch 4899, loss with penalty 1.9521116018295288
# epoch 4900, loss with penalty 1.9520928859710693
# New min loss = tensor([1.9519], grad_fn=<AddBackward0>)
# epoch 4999, loss with penalty 1.9739136695861816
# epoch 5000, loss with penalty 1.9912528991699219
# epoch 5099, loss with penalty 1.9540879726409912
# epoch 5100, loss with penalty 1.9535977840423584
# New min loss = tensor([1.9509], grad_fn=<AddBackward0>)
# epoch 5199, loss with penalty 1.9506151676177979
# epoch 5200, loss with penalty 1.950602650642395
# New min loss = tensor([1.9499], grad_fn=<AddBackward0>)
# epoch 5299, loss with penalty 8.368975639343262
# epoch 5300, loss with penalty 8.968134880065918
# epoch 5399, loss with penalty 1.951293706893921
# epoch 5400, loss with penalty 1.9513330459594727
# epoch 5499, loss with penalty 1.9491260051727295
# epoch 5500, loss with penalty 1.9491106271743774
# New min loss = tensor([1.9489], grad_fn=<AddBackward0>)
# epoch 5599, loss with penalty 2.342005968093872
# epoch 5600, loss with penalty 2.306748867034912
# epoch 5699, loss with penalty 1.9492603540420532
# epoch 5700, loss with penalty 1.9492393732070923
# New min loss = tensor([1.9479], grad_fn=<AddBackward0>)
# epoch 5799, loss with penalty 1.947584867477417
# epoch 5800, loss with penalty 1.9475754499435425
# epoch 5899, loss with penalty 1.9505677223205566
# epoch 5900, loss with penalty 1.9523025751113892
# epoch 5999, loss with penalty 1.9476312398910522
# epoch 6000, loss with penalty 1.9476113319396973
# New min loss = tensor([1.9469], grad_fn=<AddBackward0>)
# epoch 6099, loss with penalty 2.860579013824463
# epoch 6100, loss with penalty 2.4570517539978027
# epoch 6199, loss with penalty 1.948056697845459
# epoch 6200, loss with penalty 1.9480242729187012
# epoch 6299, loss with penalty 1.946211338043213
# epoch 6300, loss with penalty 1.94619619846344
# epoch 6399, loss with penalty 1.951947808265686
# epoch 6400, loss with penalty 1.9533954858779907
# epoch 6499, loss with penalty 1.946671724319458
# epoch 6500, loss with penalty 1.9466525316238403
# New min loss = tensor([1.9459], grad_fn=<AddBackward0>)
# epoch 6599, loss with penalty 2.0416479110717773
# epoch 6600, loss with penalty 2.1997811794281006
# epoch 6699, loss with penalty 1.9478355646133423
# epoch 6700, loss with penalty 1.947786569595337
# epoch 6799, loss with penalty 1.9456043243408203
# epoch 6800, loss with penalty 1.94558846950531
# epoch 6899, loss with penalty 1.9565917253494263
# epoch 6900, loss with penalty 1.9516533613204956
# epoch 6999, loss with penalty 1.946543574333191
# epoch 7000, loss with penalty 1.9465197324752808
# epoch 7099, loss with penalty 1.9565293788909912
# epoch 7100, loss with penalty 1.9649280309677124
# epoch 7199, loss with penalty 1.9479514360427856
# epoch 7200, loss with penalty 1.9479960203170776
# epoch 7299, loss with penalty 1.9453198909759521
# epoch 7300, loss with penalty 1.945304036140442
# New min loss = tensor([1.9449], grad_fn=<AddBackward0>)
# epoch 7399, loss with penalty 1.9729270935058594
# epoch 7400, loss with penalty 1.9729692935943604
# epoch 7499, loss with penalty 1.9463461637496948
# epoch 7500, loss with penalty 1.9463213682174683
# epoch 7599, loss with penalty 3.622380256652832
# epoch 7600, loss with penalty 4.754437446594238
# epoch 7699, loss with penalty 1.9473369121551514
# epoch 7700, loss with penalty 1.9473322629928589
# epoch 7799, loss with penalty 1.9449256658554077
# epoch 7800, loss with penalty 1.9449090957641602
# epoch 7899, loss with penalty 1.9505181312561035
# epoch 7900, loss with penalty 1.9488811492919922
# epoch 7999, loss with penalty 1.9454463720321655
# epoch 8000, loss with penalty 1.9454258680343628
# epoch 8099, loss with penalty 1.9493569135665894
# epoch 8100, loss with penalty 1.9556255340576172
# epoch 8199, loss with penalty 1.9455058574676514
# epoch 8200, loss with penalty 1.9454859495162964
# epoch 8299, loss with penalty 1.9731478691101074
# epoch 8300, loss with penalty 1.9576047658920288
# epoch 8399, loss with penalty 1.9454017877578735
# epoch 8400, loss with penalty 1.9453785419464111
# epoch 8499, loss with penalty 1.9552438259124756
# epoch 8500, loss with penalty 1.9487417936325073
# epoch 8599, loss with penalty 1.9451171159744263
# epoch 8600, loss with penalty 1.9450976848602295
# epoch 8699, loss with penalty 1.9495612382888794
# epoch 8700, loss with penalty 1.9476937055587769
# epoch 8799, loss with penalty 1.9447077512741089
# epoch 8800, loss with penalty 1.9446889162063599
# epoch 8899, loss with penalty 16.540042877197266
# epoch 8900, loss with penalty 13.025333404541016
# epoch 8999, loss with penalty 5.164065837860107
# epoch 9000, loss with penalty 5.142066478729248
# epoch 9099, loss with penalty 3.625783920288086
# epoch 9100, loss with penalty 3.6157732009887695
# epoch 9199, loss with penalty 2.9440665245056152
# epoch 9200, loss with penalty 2.9396750926971436
# epoch 9299, loss with penalty 2.6285884380340576
# epoch 9300, loss with penalty 2.6263468265533447
# epoch 9399, loss with penalty 2.4519214630126953
# epoch 9400, loss with penalty 2.4505257606506348
# epoch 9499, loss with penalty 2.3346612453460693
# epoch 9500, loss with penalty 2.33367657661438
# epoch 9599, loss with penalty 2.2505080699920654
# epoch 9600, loss with penalty 2.2497949600219727
# epoch 9699, loss with penalty 2.189239978790283
# epoch 9700, loss with penalty 2.188720464706421
# epoch 9799, loss with penalty 2.1450743675231934
# epoch 9800, loss with penalty 2.144705295562744
# epoch 9899, loss with penalty 2.113646984100342
# epoch 9900, loss with penalty 2.1133832931518555
# epoch 9999, loss with penalty 2.0914249420166016
# epoch 10000, loss with penalty 2.0912396907806396
# epoch 10099, loss with penalty 2.075650453567505
# epoch 10100, loss with penalty 2.0755176544189453
# epoch 10199, loss with penalty 2.0642893314361572
# epoch 10200, loss with penalty 2.0641915798187256
# epoch 10299, loss with penalty 2.0559046268463135
# epoch 10300, loss with penalty 2.055833339691162
# epoch 10399, loss with penalty 2.0495145320892334
# epoch 10400, loss with penalty 2.0494582653045654
# epoch 10499, loss with penalty 2.0444717407226562
# epoch 10500, loss with penalty 2.044426679611206
# epoch 10599, loss with penalty 2.0403435230255127
# epoch 10600, loss with penalty 2.040306329727173
# epoch 10699, loss with penalty 2.036846876144409
# epoch 10700, loss with penalty 2.036815643310547
# epoch 10799, loss with penalty 2.0337963104248047
# epoch 10800, loss with penalty 2.0337681770324707
# epoch 10899, loss with penalty 2.0310659408569336
# epoch 10900, loss with penalty 2.0310404300689697
# epoch 10999, loss with penalty 2.028566598892212
# epoch 11000, loss with penalty 2.0285439491271973
# epoch 11099, loss with penalty 2.026240587234497
# epoch 11100, loss with penalty 2.026216506958008
# epoch 11199, loss with penalty 2.024031400680542
# epoch 11200, loss with penalty 2.0240094661712646
# epoch 11299, loss with penalty 2.0219058990478516
# epoch 11300, loss with penalty 2.0218868255615234
# epoch 11399, loss with penalty 2.019833564758301
# epoch 11400, loss with penalty 2.019810438156128
# epoch 11499, loss with penalty 2.0177841186523438
# epoch 11500, loss with penalty 2.017763376235962
# epoch 11599, loss with penalty 2.0157337188720703
# epoch 11600, loss with penalty 2.0157148838043213
# epoch 11699, loss with penalty 2.013662815093994
# epoch 11700, loss with penalty 2.0136406421661377
# epoch 11799, loss with penalty 2.0115408897399902
# epoch 11800, loss with penalty 2.011519432067871
# epoch 11899, loss with penalty 2.009350299835205
# epoch 11900, loss with penalty 2.009329319000244
# epoch 11999, loss with penalty 2.10170578956604
# epoch 12000, loss with penalty 2.0508623123168945
# epoch 12099, loss with penalty 2.006617307662964
# epoch 12100, loss with penalty 2.0065741539001465
# epoch 12199, loss with penalty 2.0031895637512207
# epoch 12200, loss with penalty 2.003159284591675
# epoch 12299, loss with penalty 2.0377888679504395
# epoch 12300, loss with penalty 2.0570192337036133
# epoch 12399, loss with penalty 1.9990694522857666
# epoch 12400, loss with penalty 1.9990215301513672
# epoch 12499, loss with penalty 1.995228886604309
# epoch 12500, loss with penalty 1.9951961040496826
# epoch 12599, loss with penalty 2.011129379272461
# epoch 12600, loss with penalty 2.0009336471557617
# epoch 12699, loss with penalty 1.9897183179855347
# epoch 12700, loss with penalty 1.9896794557571411
# epoch 12799, loss with penalty 2.0516293048858643
# epoch 12800, loss with penalty 2.159529685974121
# epoch 12899, loss with penalty 1.9841152429580688
# epoch 12900, loss with penalty 1.984065055847168
# epoch 12999, loss with penalty 2.0100159645080566
# epoch 13000, loss with penalty 1.9914880990982056
# epoch 13099, loss with penalty 1.9824721813201904
# epoch 13100, loss with penalty 1.9842089414596558
# epoch 13199, loss with penalty 1.9782350063323975
# epoch 13200, loss with penalty 1.9779138565063477
# epoch 13299, loss with penalty 1.9906071424484253
# epoch 13300, loss with penalty 1.9849114418029785
# epoch 13399, loss with penalty 1.997719407081604
# epoch 13400, loss with penalty 1.9834672212600708
# epoch 13499, loss with penalty 2.0778095722198486
# epoch 13500, loss with penalty 2.026050090789795
# epoch 13599, loss with penalty 2.007662057876587
# epoch 13600, loss with penalty 2.0025691986083984
# epoch 13699, loss with penalty 1.9748848676681519
# epoch 13700, loss with penalty 1.9739176034927368
# epoch 13799, loss with penalty 1.9720330238342285
# epoch 13800, loss with penalty 1.9717917442321777
# epoch 13899, loss with penalty 1.9766550064086914
# epoch 13900, loss with penalty 1.9773865938186646
# epoch 13999, loss with penalty 2.2264397144317627
# epoch 14000, loss with penalty 2.333299398422241
# epoch 14099, loss with penalty 2.0010557174682617
# epoch 14100, loss with penalty 1.9959967136383057
# epoch 14199, loss with penalty 2.6436119079589844
# epoch 14200, loss with penalty 2.7071733474731445
# epoch 14299, loss with penalty 1.9755781888961792
# epoch 14300, loss with penalty 1.9798139333724976
# epoch 14399, loss with penalty 3.4012322425842285
# epoch 14400, loss with penalty 3.6452367305755615
# epoch 14499, loss with penalty 2.025252103805542
# epoch 14500, loss with penalty 2.0278515815734863
# epoch 14599, loss with penalty 1.9988312721252441
# epoch 14600, loss with penalty 2.025188684463501
# epoch 14699, loss with penalty 2.11075758934021
# epoch 14700, loss with penalty 2.216355085372925
# epoch 14799, loss with penalty 2.096167802810669
# epoch 14800, loss with penalty 2.148097276687622
# epoch 14899, loss with penalty 2.0032520294189453
# epoch 14900, loss with penalty 2.0488572120666504
# epoch 14999, loss with penalty 2.01120662689209
# Using potential function defined as class takes 4769.186074972153
# Before normalization:
# tensor([[-0.0236,  0.0555, -0.0594,  0.0186, -0.0711, -0.0157,  0.0453,  0.0513,
#           0.0672, -0.0771,  0.1234,  0.0624, -0.0369, -0.1360,  0.0412, -0.1187,
#          -0.0027, -0.0229, -0.0739,  0.0252,  0.1209,  0.0831,  0.0880,  0.0848,
#           0.0586,  0.0179, -0.0634, -0.0555,  0.1257, -0.1050, -0.0199,  0.0329,
#          -0.1043, -0.0477, -0.0347,  0.0181, -0.1080,  0.0925,  0.0422, -0.0308,
#           0.1249,  0.0614,  0.0469, -0.0303, -0.0212,  0.0245, -0.1045,  0.0303,
#           0.0487, -0.0013, -0.0236, -0.1482,  0.0497, -0.0324,  0.0352,  0.0560,
#          -0.0383, -0.0809, -0.0067,  0.1157]])
# tensor([-0.0554])
# After normalization:
# tensor([[-0.0237,  0.0557, -0.0596,  0.0187, -0.0713, -0.0158,  0.0454,  0.0515,
#           0.0675, -0.0774,  0.1239,  0.0626, -0.0370, -0.1365,  0.0414, -0.1192,
#          -0.0027, -0.0230, -0.0742,  0.0253,  0.1214,  0.0834,  0.0883,  0.0851,
#           0.0588,  0.0180, -0.0636, -0.0557,  0.1262, -0.1054, -0.0200,  0.0330,
#          -0.1047, -0.0479, -0.0349,  0.0182, -0.1084,  0.0928,  0.0424, -0.0310,
#           0.1253,  0.0616,  0.0470, -0.0304, -0.0213,  0.0246, -0.1049,  0.0305,
#           0.0489, -0.0013, -0.0237, -0.1488,  0.0499, -0.0325,  0.0353,  0.0562,
#          -0.0385, -0.0813, -0.0067,  0.1162]])
# tensor([-0.0557])
# c value = tensor([1.0039], grad_fn=<MulBackward0>)
# Before normalization:
# tensor([[-4.7932e-02,  3.2438e-03,  2.1311e-03,  4.4725e-04, -1.8094e-02,
#           5.6357e-02,  7.6217e-04,  1.1552e-04, -1.2565e-03, -6.8881e-03,
#           7.6556e-02,  1.3823e-03, -9.1416e-06,  1.0900e-02,  2.2935e-04,
#           5.8706e-02, -2.8729e-02,  1.6990e-03, -1.8985e-03, -1.4907e-03,
#          -2.7329e-02, -7.2517e-04, -5.9288e-05,  6.6592e-03, -5.8779e-06,
#          -2.1044e-03, -3.2163e-03,  5.9642e-03, -4.0976e-03,  1.2825e-03,
#          -3.0546e-02,  6.1636e-04,  7.7017e-04,  3.4691e-03,  7.4473e-04,
#          -2.1784e-03,  2.2638e-03, -4.9705e-03,  1.1613e-03, -1.8338e-02,
#          -1.8015e-03,  2.4864e-03,  3.9663e-04,  2.0599e-03, -9.5405e-02,
#           1.0570e-01, -3.8318e-03,  1.3334e-03,  1.4219e-03,  1.4841e-03,
#           2.1463e-03,  5.6334e-02,  1.5140e-03, -1.7790e-02,  3.5308e-04,
#          -4.7302e-05, -3.7621e-04,  1.1015e-03,  1.5622e-02, -4.1454e-03]])
# tensor([-0.0264])
# After normalization:
# tensor([[-4.7954e-02,  3.2453e-03,  2.1321e-03,  4.4746e-04, -1.8103e-02,
#           5.6383e-02,  7.6252e-04,  1.1558e-04, -1.2571e-03, -6.8913e-03,
#           7.6591e-02,  1.3829e-03, -9.1458e-06,  1.0905e-02,  2.2946e-04,
#           5.8733e-02, -2.8743e-02,  1.6998e-03, -1.8994e-03, -1.4914e-03,
#          -2.7342e-02, -7.2551e-04, -5.9316e-05,  6.6623e-03, -5.8806e-06,
#          -2.1054e-03, -3.2178e-03,  5.9669e-03, -4.0996e-03,  1.2831e-03,
#          -3.0561e-02,  6.1665e-04,  7.7052e-04,  3.4707e-03,  7.4507e-04,
#          -2.1794e-03,  2.2648e-03, -4.9728e-03,  1.1619e-03, -1.8346e-02,
#          -1.8023e-03,  2.4875e-03,  3.9682e-04,  2.0608e-03, -9.5449e-02,
#           1.0575e-01, -3.8336e-03,  1.3340e-03,  1.4225e-03,  1.4848e-03,
#           2.1473e-03,  5.6360e-02,  1.5147e-03, -1.7798e-02,  3.5324e-04,
#          -4.7324e-05, -3.7638e-04,  1.1020e-03,  1.5629e-02, -4.1473e-03]])
# tensor([-0.0264])
# c value = tensor([1.0005], grad_fn=<MulBackward0>)

# %%
del model_21_sin
del adam_opt_21_sin

model_21_sin = Nonlinear_2(layer_width=60, use_sin=True)
adam_opt_21_sin = torch.optim.Adam(model_21_sin.parameters(), 
                                    lr=learningRate, 
                                    betas=(0.9, 0.999), 
                                    eps=1e-08, 
                                    weight_decay=0, 
                                    amsgrad=False)

res2_21_sin = auto_test_documentation(model_21_sin, adam_opt_21_sin, p_fn5, 
                                      model_name='model_21_sin_pfn5',
                                      res_path=RESULT_PATH,
                                      loss_fname='loss_21_sin_pfn5',
                                      loss_with_pen_fname = 'loss_pen_21_sin_pfn5')
# Out:
# Start time is 2022-08-10 04:49:41.992818-04:00
# Initiate first min loss = tensor([143.6502], grad_fn=<AddBackward0>)
# epoch 0, loss with penalty 143.65016174316406
# New min loss = tensor([56.1880], grad_fn=<AddBackward0>)
# New min loss = tensor([3.4609], grad_fn=<AddBackward0>)
# New min loss = tensor([2.8140], grad_fn=<AddBackward0>)
# New min loss = tensor([2.6615], grad_fn=<AddBackward0>)
# New min loss = tensor([2.4508], grad_fn=<AddBackward0>)
# New min loss = tensor([2.2380], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0595], grad_fn=<AddBackward0>)
# New min loss = tensor([2.0152], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9867], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9597], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9463], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9314], grad_fn=<AddBackward0>)
# New min loss = tensor([1.9163], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8942], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8776], grad_fn=<AddBackward0>)
# epoch 99, loss with penalty 1.877373218536377
# New min loss = tensor([1.8647], grad_fn=<AddBackward0>)
# epoch 100, loss with penalty 1.8646637201309204
# New min loss = tensor([1.8555], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8535], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8520], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8391], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8320], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8261], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8245], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8157], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8142], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8075], grad_fn=<AddBackward0>)
# New min loss = tensor([1.8023], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7986], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7926], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7902], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7886], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7838], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7797], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7780], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7748], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7703], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7678], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7654], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7614], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7582], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7559], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7526], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7491], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7465], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7437], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7403], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7375], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7349], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7318], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7288], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7262], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7233], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7203], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7177], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7150], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7121], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7095], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7069], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7041], grad_fn=<AddBackward0>)
# New min loss = tensor([1.7014], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6988], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6962], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6935], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6910], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6884], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6858], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6834], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6809], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6783], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6759], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6735], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6710], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6686], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6662], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6638], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6615], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6591], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6568], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6545], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6522], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6499], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6477], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6455], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6432], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6410], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6389], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6367], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6346], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6324], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6303], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6282], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6262], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6241], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6220], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6200], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6180], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6160], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6140], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6121], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6101], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6082], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6063], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6044], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6025], grad_fn=<AddBackward0>)
# New min loss = tensor([1.6006], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5988], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5970], grad_fn=<AddBackward0>)
# epoch 199, loss with penalty 1.5969518423080444
# New min loss = tensor([1.5951], grad_fn=<AddBackward0>)
# epoch 200, loss with penalty 1.5951290130615234
# New min loss = tensor([1.5933], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5915], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5898], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5880], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5863], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5845], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5828], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5811], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5794], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5777], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5761], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5744], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5728], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5712], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5696], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5680], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5664], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5648], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5633], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5618], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5602], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5587], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5572], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5557], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5543], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5528], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5514], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5499], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5485], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5471], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5457], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5443], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5429], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5416], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5402], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5389], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5376], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5362], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5349], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5336], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5324], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5311], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5298], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5286], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5273], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5261], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5249], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5237], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5225], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5213], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5201], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5190], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5178], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5167], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5155], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5144], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5133], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5122], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5111], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5100], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5089], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5079], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5068], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5058], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5047], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5037], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5027], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5017], grad_fn=<AddBackward0>)
# New min loss = tensor([1.5007], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4987], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4967], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4948], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4930], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4911], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4893], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4875], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4858], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4841], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4824], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4807], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4791], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4775], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4759], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4744], grad_fn=<AddBackward0>)
# epoch 299, loss with penalty 1.4743733406066895
# epoch 300, loss with penalty 1.4736101627349854
# New min loss = tensor([1.4729], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4714], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4699], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4685], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4671], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4657], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4643], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4630], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4617], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4604], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4591], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4578], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4566], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4554], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4542], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4531], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4519], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4508], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4497], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4486], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4476], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4465], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4455], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4445], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4430], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4416], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4402], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4389], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4375], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4362], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4350], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4338], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4326], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4314], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4303], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4292], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4282], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4271], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4261], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4248], grad_fn=<AddBackward0>)
# epoch 399, loss with penalty 1.4238554239273071
# New min loss = tensor([1.4235], grad_fn=<AddBackward0>)
# epoch 400, loss with penalty 1.423545241355896
# New min loss = tensor([1.4223], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4212], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4200], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4189], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4179], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4169], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4156], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4145], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4134], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4123], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4113], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4101], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4090], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4079], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4069], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4058], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4047], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4036], grad_fn=<AddBackward0>)
# epoch 499, loss with penalty 1.40304696559906
# epoch 500, loss with penalty 1.4029145240783691
# New min loss = tensor([1.4025], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4015], grad_fn=<AddBackward0>)
# New min loss = tensor([1.4005], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3993], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3983], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3973], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3962], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3952], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3942], grad_fn=<AddBackward0>)
# epoch 599, loss with penalty 1.3933666944503784
# epoch 600, loss with penalty 1.3932958841323853
# New min loss = tensor([1.3932], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3921], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3911], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3901], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3891], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3881], grad_fn=<AddBackward0>)
# epoch 699, loss with penalty 1.387566089630127
# epoch 700, loss with penalty 1.3875192403793335
# New min loss = tensor([1.3870], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3860], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3850], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3840], grad_fn=<AddBackward0>)
# epoch 799, loss with penalty 1.3833743333816528
# epoch 800, loss with penalty 1.3833374977111816
# New min loss = tensor([1.3829], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3819], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3809], grad_fn=<AddBackward0>)
# epoch 899, loss with penalty 1.3801807165145874
# epoch 900, loss with penalty 1.380153775215149
# New min loss = tensor([1.3799], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3789], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3779], grad_fn=<AddBackward0>)
# epoch 999, loss with penalty 1.377766489982605
# epoch 1000, loss with penalty 1.3777456283569336
# New min loss = tensor([1.3768], grad_fn=<AddBackward0>)
# epoch 1099, loss with penalty 1.375978708267212
# epoch 1100, loss with penalty 1.3759632110595703
# New min loss = tensor([1.3758], grad_fn=<AddBackward0>)
# New min loss = tensor([1.3748], grad_fn=<AddBackward0>)
# epoch 1199, loss with penalty 1.3746647834777832
# epoch 1200, loss with penalty 1.3746534585952759
# New min loss = tensor([1.3738], grad_fn=<AddBackward0>)
# epoch 1299, loss with penalty 1.3736988306045532
# epoch 1300, loss with penalty 1.3736913204193115
# epoch 1399, loss with penalty 1.3729782104492188
# epoch 1400, loss with penalty 1.3729723691940308
# New min loss = tensor([1.3728], grad_fn=<AddBackward0>)
# epoch 1499, loss with penalty 1.3724247217178345
# epoch 1500, loss with penalty 1.3724182844161987
# epoch 1599, loss with penalty 1.371984601020813
# epoch 1600, loss with penalty 1.3719803094863892
# New min loss = tensor([1.3718], grad_fn=<AddBackward0>)
# epoch 1699, loss with penalty 1.9916120767593384
# epoch 1700, loss with penalty 2.4720892906188965
# epoch 1799, loss with penalty 1.3726592063903809
# epoch 1800, loss with penalty 1.3725180625915527
# epoch 1899, loss with penalty 1.3716211318969727
# epoch 1900, loss with penalty 1.3716155290603638
# epoch 1999, loss with penalty 4.308234214782715
# epoch 2000, loss with penalty 5.335661888122559
# epoch 2099, loss with penalty 1.3725649118423462
# epoch 2100, loss with penalty 1.3725892305374146
# epoch 2199, loss with penalty 1.3714251518249512
# epoch 2200, loss with penalty 1.371417760848999
# epoch 2299, loss with penalty 1.37092125415802
# epoch 2300, loss with penalty 1.3709455728530884
# epoch 2399, loss with penalty 1.3738197088241577
# epoch 2400, loss with penalty 1.374066948890686
# epoch 2499, loss with penalty 1.371169090270996
# epoch 2500, loss with penalty 1.371161699295044
# New min loss = tensor([1.3708], grad_fn=<AddBackward0>)
# epoch 2599, loss with penalty 1.3725095987319946
# epoch 2600, loss with penalty 1.3735343217849731
# epoch 2699, loss with penalty 1.372648000717163
# epoch 2700, loss with penalty 1.3722515106201172
# epoch 2799, loss with penalty 1.3708064556121826
# epoch 2800, loss with penalty 1.3707984685897827
# epoch 2899, loss with penalty 1.9006099700927734
# epoch 2900, loss with penalty 2.341367483139038
# epoch 2999, loss with penalty 1.3718324899673462
# epoch 3000, loss with penalty 1.3718980550765991
# epoch 3099, loss with penalty 1.3705737590789795
# epoch 3100, loss with penalty 1.370566725730896
# epoch 3199, loss with penalty 1.3703380823135376
# epoch 3200, loss with penalty 1.3704553842544556
# epoch 3299, loss with penalty 1.3725489377975464
# epoch 3300, loss with penalty 1.3722965717315674
# epoch 3399, loss with penalty 1.3704168796539307
# epoch 3400, loss with penalty 1.3704094886779785
# epoch 3499, loss with penalty 1.7553555965423584
# epoch 3500, loss with penalty 2.5699453353881836
# epoch 3599, loss with penalty 1.3709745407104492
# epoch 3600, loss with penalty 1.3709520101547241
# epoch 3699, loss with penalty 1.3700816631317139
# epoch 3700, loss with penalty 1.370077133178711
# epoch 3799, loss with penalty 1.3762688636779785
# epoch 3800, loss with penalty 1.3744455575942993
# epoch 3899, loss with penalty 1.3702582120895386
# epoch 3900, loss with penalty 1.370252251625061
# epoch 3999, loss with penalty 1.6531802415847778
# epoch 4000, loss with penalty 1.465122103691101
# epoch 4099, loss with penalty 1.3704679012298584
# epoch 4100, loss with penalty 1.3704549074172974
# epoch 4199, loss with penalty 1.3882962465286255
# epoch 4200, loss with penalty 1.4121092557907104
# epoch 4299, loss with penalty 1.3703511953353882
# epoch 4300, loss with penalty 1.370339274406433
# epoch 4399, loss with penalty 1.389744520187378
# epoch 4400, loss with penalty 1.4049828052520752
# epoch 4499, loss with penalty 1.3720334768295288
# epoch 4500, loss with penalty 1.3728841543197632
# epoch 4599, loss with penalty 1.3705689907073975
# epoch 4600, loss with penalty 1.3705978393554688
# epoch 4699, loss with penalty 1.3723182678222656
# epoch 4700, loss with penalty 1.3721113204956055
# epoch 4799, loss with penalty 1.9044275283813477
# epoch 4800, loss with penalty 1.7877271175384521
# epoch 4899, loss with penalty 1.3711707592010498
# epoch 4900, loss with penalty 1.3714643716812134
# epoch 4999, loss with penalty 1.3708512783050537
# epoch 5000, loss with penalty 1.3707499504089355
# epoch 5099, loss with penalty 1.3710402250289917
# epoch 5100, loss with penalty 1.370705008506775
# epoch 5199, loss with penalty 1.3733432292938232
# epoch 5200, loss with penalty 1.3752557039260864
# epoch 5299, loss with penalty 1.3721367120742798
# epoch 5300, loss with penalty 1.3754712343215942
# epoch 5399, loss with penalty 1.4053480625152588
# epoch 5400, loss with penalty 1.3941956758499146
# epoch 5499, loss with penalty 1.3903831243515015
# epoch 5500, loss with penalty 1.3880996704101562
# epoch 5599, loss with penalty 1.3733564615249634
# epoch 5600, loss with penalty 1.3725708723068237
# epoch 5699, loss with penalty 1.370900273323059
# epoch 5700, loss with penalty 1.3705404996871948
# epoch 5799, loss with penalty 1.3850781917572021
# epoch 5800, loss with penalty 1.382156491279602
# epoch 5899, loss with penalty 1.5699641704559326
# epoch 5900, loss with penalty 1.4743218421936035
# epoch 5999, loss with penalty 1.6855226755142212
# epoch 6000, loss with penalty 1.7827632427215576
# epoch 6099, loss with penalty 1.7906948328018188
# epoch 6100, loss with penalty 1.8598806858062744
# epoch 6199, loss with penalty 1.6758320331573486
# epoch 6200, loss with penalty 1.4198096990585327
# epoch 6299, loss with penalty 1.7771955728530884
# epoch 6300, loss with penalty 1.9291999340057373
# epoch 6399, loss with penalty 1.457496166229248
# epoch 6400, loss with penalty 1.3814648389816284
# epoch 6499, loss with penalty 1.3870418071746826
# epoch 6500, loss with penalty 1.4003047943115234
# epoch 6599, loss with penalty 1.388018012046814
# epoch 6600, loss with penalty 1.391033411026001
# epoch 6699, loss with penalty 1.4244810342788696
# epoch 6700, loss with penalty 1.4191802740097046
# epoch 6799, loss with penalty 1.6426267623901367
# epoch 6800, loss with penalty 1.6019755601882935
# epoch 6899, loss with penalty 1.3782883882522583
# epoch 6900, loss with penalty 1.3797086477279663
# epoch 6999, loss with penalty 1.4866697788238525
# epoch 7000, loss with penalty 1.5034273862838745
# epoch 7099, loss with penalty 1.3764691352844238
# epoch 7100, loss with penalty 1.3730448484420776
# epoch 7199, loss with penalty 1.5455358028411865
# epoch 7200, loss with penalty 1.6242773532867432
# epoch 7299, loss with penalty 1.3710273504257202
# epoch 7300, loss with penalty 1.3744421005249023
# epoch 7399, loss with penalty 1.4045605659484863
# epoch 7400, loss with penalty 1.4119532108306885
# epoch 7499, loss with penalty 1.454733967781067
# epoch 7500, loss with penalty 1.4561983346939087
# epoch 7599, loss with penalty 1.3716683387756348
# epoch 7600, loss with penalty 1.3738818168640137
# epoch 7699, loss with penalty 1.3816237449645996
# epoch 7700, loss with penalty 1.3804614543914795
# epoch 7799, loss with penalty 1.4119250774383545
# epoch 7800, loss with penalty 1.4251556396484375
# epoch 7899, loss with penalty 1.4049971103668213
# epoch 7900, loss with penalty 1.405184268951416
# epoch 7999, loss with penalty 1.3830019235610962
# epoch 8000, loss with penalty 1.384811282157898
# epoch 8099, loss with penalty 1.379385232925415
# epoch 8100, loss with penalty 1.377274513244629
# epoch 8199, loss with penalty 1.4028239250183105
# epoch 8200, loss with penalty 1.3990633487701416
# epoch 8299, loss with penalty 1.3909579515457153
# epoch 8300, loss with penalty 1.373620867729187
# epoch 8399, loss with penalty 1.4142056703567505
# epoch 8400, loss with penalty 1.4299001693725586
# epoch 8499, loss with penalty 1.395399570465088
# epoch 8500, loss with penalty 1.4000945091247559
# New min loss = tensor([1.3698], grad_fn=<AddBackward0>)
# epoch 8599, loss with penalty 1.430318832397461
# epoch 8600, loss with penalty 1.4431830644607544
# epoch 8699, loss with penalty 1.4280606508255005
# epoch 8700, loss with penalty 1.389501929283142
# epoch 8799, loss with penalty 1.4458351135253906
# epoch 8800, loss with penalty 1.4133716821670532
# epoch 8899, loss with penalty 1.3726972341537476
# epoch 8900, loss with penalty 1.3704965114593506
# epoch 8999, loss with penalty 1.3819104433059692
# epoch 9000, loss with penalty 1.3752872943878174
# epoch 9099, loss with penalty 1.3763148784637451
# epoch 9100, loss with penalty 1.3722312450408936
# epoch 9199, loss with penalty 1.3810759782791138
# epoch 9200, loss with penalty 1.382628083229065
# epoch 9299, loss with penalty 1.3703725337982178
# epoch 9300, loss with penalty 1.3701666593551636
# epoch 9399, loss with penalty 1.3713897466659546
# epoch 9400, loss with penalty 1.3722374439239502
# epoch 9499, loss with penalty 1.4083611965179443
# epoch 9500, loss with penalty 1.4224026203155518
# epoch 9599, loss with penalty 1.4070996046066284
# epoch 9600, loss with penalty 1.4091134071350098
# epoch 9699, loss with penalty 1.382883071899414
# epoch 9700, loss with penalty 1.3965970277786255
# epoch 9799, loss with penalty 1.378801941871643
# epoch 9800, loss with penalty 1.3821637630462646
# epoch 9899, loss with penalty 1.4225295782089233
# epoch 9900, loss with penalty 1.4634133577346802
# epoch 9999, loss with penalty 1.3694912195205688
# epoch 10000, loss with penalty 1.3693758249282837
# epoch 10099, loss with penalty 7.075983047485352
# epoch 10100, loss with penalty 7.458057880401611
# epoch 10199, loss with penalty 5.556302070617676
# epoch 10200, loss with penalty 5.542158126831055
# epoch 10299, loss with penalty 4.3974151611328125
# epoch 10300, loss with penalty 4.388732433319092
# epoch 10399, loss with penalty 3.723494291305542
# epoch 10400, loss with penalty 3.718228340148926
# epoch 10499, loss with penalty 3.2850592136383057
# epoch 10500, loss with penalty 3.281406879425049
# epoch 10599, loss with penalty 2.9713504314422607
# epoch 10600, loss with penalty 2.968665361404419
# epoch 10699, loss with penalty 2.736478805541992
# epoch 10700, loss with penalty 2.7344350814819336
# epoch 10799, loss with penalty 2.5552287101745605
# epoch 10800, loss with penalty 2.5536251068115234
# epoch 10899, loss with penalty 2.4115960597991943
# epoch 10900, loss with penalty 2.4103119373321533
# epoch 10999, loss with penalty 2.2947542667388916
# epoch 11000, loss with penalty 2.2936923503875732
# epoch 11099, loss with penalty 2.197207450866699
# epoch 11100, loss with penalty 2.19630765914917
# epoch 11199, loss with penalty 2.113781690597534
# epoch 11200, loss with penalty 2.1130049228668213
# epoch 11299, loss with penalty 2.0409281253814697
# epoch 11300, loss with penalty 2.0402450561523438
# epoch 11399, loss with penalty 1.9762201309204102
# epoch 11400, loss with penalty 1.9756100177764893
# epoch 11499, loss with penalty 1.9180083274841309
# epoch 11500, loss with penalty 1.9174526929855347
# epoch 11599, loss with penalty 1.8651413917541504
# epoch 11600, loss with penalty 1.8646374940872192
# epoch 11699, loss with penalty 1.816835880279541
# epoch 11700, loss with penalty 1.8163734674453735
# epoch 11799, loss with penalty 1.772519826889038
# epoch 11800, loss with penalty 1.772096872329712
# epoch 11899, loss with penalty 1.7317821979522705
# epoch 11900, loss with penalty 1.731393575668335
# epoch 11999, loss with penalty 1.6943137645721436
# epoch 12000, loss with penalty 1.6939536333084106
# epoch 12099, loss with penalty 1.659872055053711
# epoch 12100, loss with penalty 1.659540057182312
# epoch 12199, loss with penalty 1.628266453742981
# epoch 12200, loss with penalty 1.6279650926589966
# epoch 12299, loss with penalty 1.5993462800979614
# epoch 12300, loss with penalty 1.5990729331970215
# epoch 12399, loss with penalty 1.5729773044586182
# epoch 12400, loss with penalty 1.5727280378341675
# epoch 12499, loss with penalty 1.549041748046875
# epoch 12500, loss with penalty 1.5488150119781494
# epoch 12599, loss with penalty 1.5274229049682617
# epoch 12600, loss with penalty 1.5272194147109985
# epoch 12699, loss with penalty 1.5080116987228394
# epoch 12700, loss with penalty 1.507829189300537
# epoch 12799, loss with penalty 1.4906946420669556
# epoch 12800, loss with penalty 1.4905322790145874
# epoch 12899, loss with penalty 1.475346565246582
# epoch 12900, loss with penalty 1.4752033948898315
# epoch 12999, loss with penalty 1.4618409872055054
# epoch 13000, loss with penalty 1.4617164134979248
# epoch 13099, loss with penalty 1.4500426054000854
# epoch 13100, loss with penalty 1.4499332904815674
# epoch 13199, loss with penalty 1.4398061037063599
# epoch 13200, loss with penalty 1.4397099018096924
# epoch 13299, loss with penalty 1.4309817552566528
# epoch 13300, loss with penalty 1.4309009313583374
# epoch 13399, loss with penalty 1.423429012298584
# epoch 13400, loss with penalty 1.423359751701355
# epoch 13499, loss with penalty 1.4169939756393433
# epoch 13500, loss with penalty 1.4169340133666992
# epoch 13599, loss with penalty 1.4115346670150757
# epoch 13600, loss with penalty 1.4114842414855957
# epoch 13699, loss with penalty 1.4069159030914307
# epoch 13700, loss with penalty 1.4068742990493774
# epoch 13799, loss with penalty 1.4030190706253052
# epoch 13800, loss with penalty 1.4029829502105713
# epoch 13899, loss with penalty 1.3997234106063843
# epoch 13900, loss with penalty 1.3996946811676025
# epoch 13999, loss with penalty 1.3969347476959229
# epoch 14000, loss with penalty 1.396909475326538
# epoch 14099, loss with penalty 1.3945635557174683
# epoch 14100, loss with penalty 1.39454185962677
# epoch 14199, loss with penalty 1.3925343751907349
# epoch 14200, loss with penalty 1.3925151824951172
# epoch 14299, loss with penalty 1.3907862901687622
# epoch 14300, loss with penalty 1.3907705545425415
# epoch 14399, loss with penalty 1.3892664909362793
# epoch 14400, loss with penalty 1.3892508745193481
# epoch 14499, loss with penalty 1.387929081916809
# epoch 14500, loss with penalty 1.3879157304763794
# epoch 14599, loss with penalty 1.3867419958114624
# epoch 14600, loss with penalty 1.3867305517196655
# epoch 14699, loss with penalty 1.3856755495071411
# epoch 14700, loss with penalty 1.385666012763977
# epoch 14799, loss with penalty 1.3847112655639648
# epoch 14800, loss with penalty 1.3847020864486694
# epoch 14899, loss with penalty 1.3838294744491577
# epoch 14900, loss with penalty 1.3838210105895996
# epoch 14999, loss with penalty 1.3830180168151855
# Using potential function defined as class takes 4848.583860874176
# Before normalization:
# tensor([[-0.0893, -0.0740,  0.0480,  0.1002,  0.0843,  0.0869,  0.0785,  0.0368,
#          -0.0844, -0.1861, -0.0128, -0.2685,  0.2176, -0.0695, -0.0954, -0.0541,
#           0.0096,  0.0802, -0.0498, -0.1293, -0.1231, -0.0491, -0.0963,  0.0993,
#           0.1012, -0.0150, -0.0935, -0.2141,  0.0289, -0.1419,  0.0732,  0.0481,
#          -0.0616, -0.0742,  0.0430,  0.1153,  0.2607, -0.0835, -0.0157, -0.0524,
#           0.0133,  0.0087, -0.1468,  0.0545,  0.0019, -0.0952,  0.0729,  0.1304,
#          -0.0541, -0.0183, -0.0480,  0.0978,  0.1969, -0.2432,  0.0238, -0.1056,
#           0.0410, -0.2736,  0.0235,  0.1455]])
# tensor([-0.2012])
# After normalization:
# tensor([[-0.0893, -0.0740,  0.0480,  0.1002,  0.0843,  0.0869,  0.0785,  0.0368,
#          -0.0845, -0.1862, -0.0128, -0.2686,  0.2177, -0.0695, -0.0954, -0.0541,
#           0.0096,  0.0802, -0.0498, -0.1294, -0.1232, -0.0491, -0.0964,  0.0993,
#           0.1012, -0.0150, -0.0935, -0.2142,  0.0289, -0.1420,  0.0732,  0.0481,
#          -0.0616, -0.0742,  0.0430,  0.1154,  0.2608, -0.0835, -0.0157, -0.0524,
#           0.0133,  0.0087, -0.1468,  0.0545,  0.0019, -0.0952,  0.0729,  0.1305,
#          -0.0541, -0.0183, -0.0480,  0.0978,  0.1970, -0.2433,  0.0238, -0.1057,
#           0.0410, -0.2736,  0.0235,  0.1455]])
# tensor([-0.2012])
# c value = tensor([1.0003], grad_fn=<MulBackward0>)
# Before normalization:
# tensor([[-4.1775e-04,  1.2392e-04, -1.2949e-04, -2.1338e-04, -4.8077e-05,
#           7.7134e-04, -7.1179e-02,  7.5991e-03, -7.6212e-06, -1.0173e-01,
#           7.4036e-04, -5.6988e-06, -1.5454e-03, -1.1492e-04, -7.2664e-05,
#          -2.3212e-03, -2.5826e-04, -2.6585e-05, -2.3153e-04, -2.6288e-03,
#           2.3455e-04, -7.6550e-04,  2.0212e-04,  2.2069e-04,  4.8622e-04,
#           2.9854e-05, -1.1269e-03, -7.2196e-02, -7.0549e-05,  7.5954e-04,
#          -8.1790e-06, -4.9673e-04, -1.5236e-04,  2.0697e-04, -4.6739e-04,
#           1.1303e-03,  4.8398e-04, -1.2659e-04,  2.1349e-02, -5.8882e-04,
#           3.6450e-02, -8.3999e-05,  9.5926e-04,  1.5553e-03,  7.2281e-05,
#           4.2974e-04,  1.7132e-04, -2.5796e-04, -3.7979e-04,  3.1906e-03,
#           4.6071e-04,  9.7969e-05,  2.1707e-02, -7.6435e-05,  8.5774e-04,
#           1.4764e-03, -1.0444e-04,  1.7575e-04,  1.1909e-03,  1.0581e-04]])
# tensor([0.1583])
# After normalization:
# tensor([[-4.1790e-04,  1.2396e-04, -1.2953e-04, -2.1346e-04, -4.8094e-05,
#           7.7162e-04, -7.1205e-02,  7.6018e-03, -7.6239e-06, -1.0177e-01,
#           7.4062e-04, -5.7008e-06, -1.5459e-03, -1.1496e-04, -7.2690e-05,
#          -2.3220e-03, -2.5835e-04, -2.6595e-05, -2.3161e-04, -2.6298e-03,
#           2.3463e-04, -7.6577e-04,  2.0219e-04,  2.2077e-04,  4.8639e-04,
#           2.9865e-05, -1.1273e-03, -7.2221e-02, -7.0574e-05,  7.5981e-04,
#          -8.1819e-06, -4.9690e-04, -1.5242e-04,  2.0705e-04, -4.6756e-04,
#           1.1307e-03,  4.8415e-04, -1.2664e-04,  2.1356e-02, -5.8903e-04,
#           3.6463e-02, -8.4028e-05,  9.5960e-04,  1.5559e-03,  7.2307e-05,
#           4.2989e-04,  1.7138e-04, -2.5805e-04, -3.7992e-04,  3.1917e-03,
#           4.6088e-04,  9.8004e-05,  2.1715e-02, -7.6463e-05,  8.5805e-04,
#           1.4770e-03, -1.0448e-04,  1.7581e-04,  1.1913e-03,  1.0585e-04]])
# tensor([0.1583])
# c value = tensor([1.0004], grad_fn=<MulBackward0>)

# %% [markdown]
# ### The Finite Difference Method

# %%
def finite_diff_method(discrete_points, given_fn):
    N_points = len(discrete_points)
    h = discrete_points[1]-discrete_points[0]
    c = np.sqrt(1/h)

    H = np.zeros((N_points,N_points))
    # Question: Why H has dimension (N-2) x (N-2)?
    V = np.zeros((N_points,N_points))

    for i in range (N_points):
        for j in range (N_points):
            if i == j:
                H[i][j] = -2
            elif abs(i-j) == 1:
                H[i][j] = 1
    for i in range (N_points):
        for j in range (N_points):
            if i == j:
                V[i][j] = given_fn.forward(discrete_points[i])

    A = -H/(h**2) + V
    
    eig_val, eig_vec = np.linalg.eig(A)
    sorted_id_eig_val = np.argsort(eig_val)
    # Get the indices that would sort eig_val
    z = sorted_id_eig_val[0:1]
    # eig_val[z] will return sorted first [T] value of eigenvalues.
    energies = eig_val[z]/eig_val[z][0]

    ground_state = c * eig_vec[:,z[0]]

    return (eig_val[z], ground_state)

# %%
def plot_finite_diff_sol(eig_val, ground_state, discrete_points, nn_model=None):
    plt.figure(figsize=(12,10))
    for i in range(len(eig_val)):
        y = []
        y = np.append(y, (-1) * ground_state)

        plt.plot(discrete_points,y,lw=3, label="{} ".format(i))
        plt.xlabel('x', size=14)
        plt.ylabel('$\psi$(x)',size=14)
    if nn_model != None:
        model_output = model_on_interval(nn_model, DISCRETE_POINTS)
        plt.plot(discrete_points, model_output)
    plt.legend()
    plt.title('normalized wavefunctions for a harmonic oscillator using finite difference method',size=14)
    plt.show()
    return

# %%
loss_val = epsilon_Loss_penalty(p_fn1, res1_21_sin[3], LAMBDA_PEN, U_BOUND, DISCRETE_POINTS)[0]
print("The FD method eigenvalue: " + str(eig_val[0]))
print("The NN method loss value: " + str(loss_val.item()))
# Out:
# The FD method eigenvalue: 0.8500041525597394
# The NN method loss value: 0.83415287733078

# %%
eig_val, ground_state = finite_diff_method(DISCRETE_POINTS, p_fn1)
print(eig_val[0])
plot_finite_diff_sol(eig_val, ground_state, DISCRETE_POINTS, res1_21_sin[3])
# Out:
# 0.8500041525597394

# %% [markdown]
# ### Load Results for Display

# %%
model_21sin_pfn1 = Nonlinear_2(layer_width=60, use_sin=True)
model_21sin_pfn1 = load_model(model_21sin_pfn1, RESULT_PATH + 'model_21_sin_pfn1')
# model_on_interval(model_21sin_pfn1, DISCRETE_POINTS)

# %%
model_21sin_pfn1.eval()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-c406e81ace15> in <module>
# ----> 1 model_21sin_pfn1.eval()
#
# AttributeError: '_IncompatibleKeys' object has no attribute 'eval'
